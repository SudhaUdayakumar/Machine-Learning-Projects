# %% [markdown]
# ![Housing%20Project.jpeg](attachment:Housing%20Project.jpeg)

# %% [markdown]
# # Housing Project-  Python Machine Learning

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Housing-Project---Python-Machine-Learning" data-toc-modified-id="Housing-Project---Python-Machine-Learning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Housing Project-  Python Machine Learning</a></span></li><li><span><a href="#Problem-Statement-(Given)" data-toc-modified-id="Problem-Statement-(Given)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Problem Statement (Given)</a></span></li><li><span><a href="#Choosing-the-Right-Tools" data-toc-modified-id="Choosing-the-Right-Tools-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Choosing the Right Tools</a></span><ul class="toc-item"><li><span><a href="#Importing-and-Installing-Right-Packages" data-toc-modified-id="Importing-and-Installing-Right-Packages-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Importing and Installing Right Packages</a></span></li><li><span><a href="#Handling-Warnings" data-toc-modified-id="Handling-Warnings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Handling Warnings</a></span></li></ul></li><li><span><a href="#Loading-Dataset" data-toc-modified-id="Loading-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Loading Dataset</a></span></li><li><span><a href="#Combining-the-Train-&amp;-Test-Data" data-toc-modified-id="Combining-the-Train-&amp;-Test-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Combining the Train &amp; Test Data</a></span></li><li><span><a href="#Initial-Analysis-of-Data" data-toc-modified-id="Initial-Analysis-of-Data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Initial Analysis of Data</a></span></li><li><span><a href="#Pre-processing-the-Data" data-toc-modified-id="Pre-processing-the-Data-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Pre-processing the Data</a></span><ul class="toc-item"><li><span><a href="#Dropping-the-Unwanted-Columns" data-toc-modified-id="Dropping-the-Unwanted-Columns-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Dropping the Unwanted Columns</a></span><ul class="toc-item"><li><span><a href="#Dropping-ID-column" data-toc-modified-id="Dropping-ID-column-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Dropping ID column</a></span></li><li><span><a href="#Dropping-columns-with-High-Missing-data" data-toc-modified-id="Dropping-columns-with-High-Missing-data-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Dropping columns with High Missing data</a></span></li></ul></li><li><span><a href="#Handling-Missing-Values" data-toc-modified-id="Handling-Missing-Values-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Handling Missing Values</a></span></li></ul></li><li><span><a href="#Categorizing-Categorical-&amp;-Numerical-Data" data-toc-modified-id="Categorizing-Categorical-&amp;-Numerical-Data-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Categorizing Categorical &amp; Numerical Data</a></span><ul class="toc-item"><li><span><a href="#Categorical" data-toc-modified-id="Categorical-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Categorical</a></span></li><li><span><a href="#Numerical" data-toc-modified-id="Numerical-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Numerical</a></span></li><li><span><a href="#Feature-Creation" data-toc-modified-id="Feature-Creation-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Feature Creation</a></span></li><li><span><a href="#Creating-Functions-(Inspired-by-similar-work)" data-toc-modified-id="Creating-Functions-(Inspired-by-similar-work)-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Creating Functions (Inspired by similar work)</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Bi-Variate-Analysis" data-toc-modified-id="Bi-Variate-Analysis-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Bi-Variate Analysis</a></span></li><li><span><a href="#Multivariate-Analysis" data-toc-modified-id="Multivariate-Analysis-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Multivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Correlation-matrix/heatmap" data-toc-modified-id="Correlation-matrix/heatmap-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Correlation matrix/heatmap</a></span></li></ul></li><li><span><a href="#Correlation-with-target-variable-Numerical-+-Plot" data-toc-modified-id="Correlation-with-target-variable-Numerical-+-Plot-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Correlation with target variable-Numerical + Plot</a></span></li></ul></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Skewness-Handling" data-toc-modified-id="Skewness-Handling-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Skewness Handling</a></span></li><li><span><a href="#Label-Encoding" data-toc-modified-id="Label-Encoding-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Label Encoding</a></span></li><li><span><a href="#Model-Building-Regression" data-toc-modified-id="Model-Building-Regression-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Model Building-Regression</a></span><ul class="toc-item"><li><span><a href="#Importing-Libraries-for-Model-Building-(Regression)" data-toc-modified-id="Importing-Libraries-for-Model-Building-(Regression)-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Importing Libraries for Model Building (Regression)</a></span></li></ul></li><li><span><a href="#Standard-Scalar-on-Train-Data" data-toc-modified-id="Standard-Scalar-on-Train-Data-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Standard Scalar on Train Data</a></span><ul class="toc-item"><li><span><a href="#Train-&amp;-Test-Split" data-toc-modified-id="Train-&amp;-Test-Split-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Train &amp; Test Split</a></span></li><li><span><a href="#Finding-Best-Random-State" data-toc-modified-id="Finding-Best-Random-State-14.2"><span class="toc-item-num">14.2&nbsp;&nbsp;</span>Finding Best Random State</a></span></li><li><span><a href="#Instantiating-the-Algos" data-toc-modified-id="Instantiating-the-Algos-14.3"><span class="toc-item-num">14.3&nbsp;&nbsp;</span>Instantiating the Algos</a></span></li><li><span><a href="#Building-the-Model-&amp;-Evaluation-Metrics" data-toc-modified-id="Building-the-Model-&amp;-Evaluation-Metrics-14.4"><span class="toc-item-num">14.4&nbsp;&nbsp;</span>Building the Model &amp; Evaluation Metrics</a></span></li></ul></li><li><span><a href="#PCA" data-toc-modified-id="PCA-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>PCA</a></span><ul class="toc-item"><li><span><a href="#PCA-Model-Building" data-toc-modified-id="PCA-Model-Building-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>PCA Model Building</a></span></li></ul></li><li><span><a href="#HyperParameter-Tuning" data-toc-modified-id="HyperParameter-Tuning-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>HyperParameter Tuning</a></span><ul class="toc-item"><li><span><a href="#Gradient-Boost-Regressor" data-toc-modified-id="Gradient-Boost-Regressor-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>Gradient Boost Regressor</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-16.2"><span class="toc-item-num">16.2&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li></ul></li><li><span><a href="#Regression-Forest-with-multiple-parameters" data-toc-modified-id="Regression-Forest-with-multiple-parameters-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Regression Forest with multiple parameters</a></span></li><li><span><a href="#Saving-the-Model" data-toc-modified-id="Saving-the-Model-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Saving the Model</a></span></li><li><span><a href="#Loading-the-Model" data-toc-modified-id="Loading-the-Model-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Loading the Model</a></span></li></ul></div>

# %% [markdown]
# # Problem Statement (Given)

# %% [markdown]
# # Choosing the Right Tools

# %% [markdown]
# ## Importing and Installing Right Packages

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)       # To display all the data in each column
pd.set_option('display.precision', 5)               # To display values only upto three decimal places.
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()
pd.options.display.float_format = '{:.2f}'.format  
import numpy as np
import seaborn as sns
sns.set(style='whitegrid', font_scale = 1.3, color_codes=True)
from sklearn.preprocessing import LabelEncoder


import matplotlib.pyplot as plt
# %matplotlib inline


import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Handling Warnings

# %%
warnings.filterwarnings('ignore') # ignore warnings.
# %config IPCompleter.greedy = True # autocomplete feature.
pd.options.display.max_rows = None # set maximum rows that can be displayed in notebook.
pd.options.display.max_columns = None # set maximum columns that can be displayed in notebook.
pd.options.display.precision = 4 # set the precision of floating point numbers.

# %% [markdown]
# # Loading Dataset

# %%
# Importing training dataset using pd.read_csv from local folder
df_train=pd.read_csv("housingprojecttrain.csv")
df_train["found"]=1

# %%
df_train.shape
# Out:
# (1168, 82)

# %%
df_train.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          nan     4928   Pave   NaN      IR1
# 1  889          20       RL        95.00    15865   Pave   NaN      IR1
# 2  793          60       RL        92.00     9920   Pave   NaN      IR1
# 3  110          20       RL       105.00    11751   Pave   NaN      IR1
# 4  422          20       RL          nan    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Train set loaded properly and the source column we added. Sale price our target column is also there</span>

# %%
# Importing testing dataset using pd.read_excel from local folder
df_test=pd.read_csv("housingprojecttest.csv")
df_test["found"]=2

# %%
df_test.shape
# Out:
# (292, 81)

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL        86.00    14157   Pave   NaN      IR1
# 1  1018         120       RL          nan     5814   Pave   NaN      IR1
# 2   929          20       RL          nan    11838   Pave   NaN      Reg
# 3  1148          70       RL        75.00    12000   Pave   NaN      Reg
# 4  1227          60       RL        86.00    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         HLS    AllPub    Corner       Gtl      StoneBr       Norm
# 1         Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 4         Lvl    AllPub   CulDSac       Gtl      Somerst      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Test Data loaded properly and as expected the target column, Sale price is missing. The column found which we added is listed as well </span>

# %% [markdown]
# # Combining the Train & Test Data

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have Imported the Train & Test Data which was in a Zip File in our local folder. Now we have imported them in our Jupyter notebook. It will be difficult to Pre-process data & do EDA, sepertaely for Train & Test. So lets combine both of them and work on pre-processing and EDA. While Model Building we will split our data back to Train & Test. To make the split easy, we have added a column called "source" to identify if it is train or test and we can seperate them easily</span>

# %%
df=pd.concat([df_train,df_test])
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          nan     4928   Pave   NaN      IR1
# 1  889          20       RL        95.00    15865   Pave   NaN      IR1
# 2  793          60       RL        92.00     9920   Pave   NaN      IR1
# 3  110          20       RL       105.00    11751   Pave   NaN      IR1
# 4  422          20       RL          nan    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 82)

# %%
##Stripping off white_spaces from the column name(if any)
df = df.rename(columns= lambda x: x.strip(), inplace=False)

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have combined the train & test data, so that we can clean the data together. We can then split the data and use the test data for predictions </span>

# %% [markdown]
# # Initial Analysis of Data

# %%
df.shape
# Out:
# (1460, 82)

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** There are many missing values..
#     1. Let us sort based on mean, and then remove values which are missing more than 80%
#     2. Sale Price 292 missing is expected as that column itself was not there
#     3. For all other missing data, let us analyse and see if we need to replace with mean/median/mode or merge few columns or add null values as needed etc

# %%
duplicates = df[df.duplicated()]
print('There are {} duplicates out of total {} rows'.format(duplicates.shape[0], df.shape[0]))
# Out:
# There are 0 duplicates out of total 1460 rows

# %%
df.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
# Alley               2
# LotShape            4
# LandContour         4
# Utilities           2
# LotConfig           5
# LandSlope           3
# Neighborhood       25
# Condition1          9
# Condition2          8
# BldgType            5
# HouseStyle          8
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# RoofStyle           6
# RoofMatl            8
# Exterior1st        15
# Exterior2nd        16
# MasVnrType          4
# MasVnrArea        327
# ExterQual           4
# ExterCond           5
# Foundation          6
# BsmtQual            4
# BsmtCond            4
# BsmtExposure        4
# BsmtFinType1        6
# BsmtFinSF1        637
# BsmtFinType2        6
# BsmtFinSF2        144
# BsmtUnfSF         780
# TotalBsmtSF       721
# Heating             6
# HeatingQC           5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 291
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#            Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# count 1460.00     1460.00      1201.00   1460.00      1460.00      1460.00
# mean   730.50       56.90        70.05  10516.83         6.10         5.58
# std    421.61       42.30        24.28   9981.26         1.38         1.11
# min      1.00       20.00        21.00   1300.00         1.00         1.00
# 25%    365.75       20.00        59.00   7553.50         5.00         5.00
# 50%    730.50       50.00        69.00   9478.50         6.00         5.00
# 75%   1095.25       70.00        80.00  11601.50         7.00         6.00
# max   1460.00      190.00       313.00 215245.00        10.00         9.00
#
#        YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# count    1460.00       1460.00     1452.00     1460.00     1460.00    1460.00
# mean     1971.27       1984.87      103.69      443.64       46.55     567.24
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.select_dtypes(['object','bool']).apply(lambda x: x.value_counts()).T.stack()
# Out:
# MSZoning       C (all)     10.00
#                FV          65.00
#                RH          16.00
#                RL        1151.00
#                RM         218.00
# Street         Grvl         6.00
#                Pave      1454.00
# Alley          Grvl        50.00
#                Pave        41.00
# LotShape       IR1        484.00
#                IR2         41.00
#                IR3         10.00
#                Reg        925.00
# LandContour    Bnk         63.00
#                HLS         50.00
#                Low         36.00
#                Lvl       1311.00
# Utilities      AllPub    1459.00
#                NoSeWa       1.00
# LotConfig      Corner     263.00
#                CulDSac     94.00
#                FR2         47.00
#                FR3          4.00
#                Inside    1052.00
# LandSlope      Gtl       1382.00
#                Mod         65.00
#                Sev         13.00
# Neighborhood   Blmngtn     17.00
# ...

# %% [markdown]
# # Pre-processing the Data

# %% [markdown]
# ## Dropping the Unwanted Columns

# %% [markdown]
# ### Dropping ID column

# %%
df.drop(['Id'], axis = 1, inplace = True)

# %% [markdown]
# <span style='background:yellow'>**Observation:** We dropped the ID column, as it is unique for each row of data and is not adding any value. So dropping the column </span>

# %% [markdown]
# ### Dropping columns with High Missing data

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# PoolQC          1.00
# MiscFeature     0.96
# Alley           0.94
# Fence           0.81
# FireplaceQu     0.47
# SalePrice       0.20
# LotFrontage     0.18
# GarageYrBlt     0.06
# GarageQual      0.06
# GarageCond      0.06
# GarageType      0.06
# GarageFinish    0.06
# BsmtExposure    0.03
# BsmtFinType2    0.03
# BsmtQual        0.03
# BsmtCond        0.03
# BsmtFinType1    0.03
# MasVnrArea      0.01
# MasVnrType      0.01
# Electrical      0.00
# RoofMatl        0.00
# Exterior1st     0.00
# ExterCond       0.00
# Exterior2nd     0.00
# ExterQual       0.00
# YearRemodAdd    0.00
# Foundation      0.00
# RoofStyle       0.00
# found           0.00
# YearBuilt       0.00
# LotConfig       0.00
# MSZoning        0.00
# LotArea         0.00
# Street          0.00
# LotShape        0.00
# LandContour     0.00
# Utilities       0.00
# LandSlope       0.00
# OverallCond     0.00
# Neighborhood    0.00
# Condition1      0.00
# Condition2      0.00
# BldgType        0.00
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Listed the missing values, in descending order, so we can see the columns which have missing values and we can plan them </span>

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %% [markdown]
# <span style='background:yellow'>**Observation:** The missing values are assigned in a chart format, to have a quick glance and easier to refer to the columns to delete which have greater null values</span>

# %%
# Droping those Columns have more than 80% null values
df = df.drop(["Alley","PoolQC","Fence","MiscFeature"],axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL          nan     4928   Pave      IR1         Lvl
# 1          20       RL        95.00    15865   Pave      IR1         Lvl
# 2          60       RL        92.00     9920   Pave      IR1         Lvl
# 3          20       RL       105.00    11751   Pave      IR1         Lvl
# 4          20       RL          nan    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Columns "Id" "Alley","PoolQC","Fence","MiscFeature" have been dropped and we dont see them in df.head() as well or df.columns </span>

# %% [markdown]
# ## Handling Missing Values

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %% [markdown]
# 16 attributes have missing values, Sale price we know. Others lets analyze

# %% [markdown]
# # Categorizing Categorical & Numerical Data

# %% [markdown]
# <span style='background:yellow'>**Observation:** Below we will split the data into categorical and numerical. Then we will handle the missing values seprately for each </span>

# %% [markdown]
# ## Categorical

# %%
categorical_features = df.select_dtypes(include=["object"])
categorical_features.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      IR1         Lvl    AllPub    Inside       Mod
# 2       RL   Pave      IR1         Lvl    AllPub   CulDSac       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      NPkVill       Norm       Norm   TwnhsE     1Story     Gable  CompShg
# 1        NAmes       Norm       Norm     1Fam     1Story      Flat  Tar&Grv
# 2      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3       NWAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 4       NWAmes       Norm       Norm     1Fam     1Story     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual  \
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have the categorical values seperated in a seperate df. Below we will see the missing values in table as well as chart format </span>

# %%
categorical_features.isnull().mean().sort_values(ascending=False)
# Out:
# FireplaceQu     0.47
# GarageCond      0.06
# GarageQual      0.06
# GarageFinish    0.06
# GarageType      0.06
# BsmtExposure    0.03
# BsmtFinType2    0.03
# BsmtQual        0.03
# BsmtFinType1    0.03
# BsmtCond        0.03
# MasVnrType      0.01
# Electrical      0.00
# Condition1      0.00
# Neighborhood    0.00
# Condition2      0.00
# BldgType        0.00
# SaleCondition   0.00
# LotConfig       0.00
# LandSlope       0.00
# RoofStyle       0.00
# Utilities       0.00
# LandContour     0.00
# LotShape        0.00
# Street          0.00
# HouseStyle      0.00
# Foundation      0.00
# RoofMatl        0.00
# Exterior1st     0.00
# Exterior2nd     0.00
# ExterQual       0.00
# ExterCond       0.00
# SaleType        0.00
# Heating         0.00
# HeatingQC       0.00
# CentralAir      0.00
# KitchenQual     0.00
# Functional      0.00
# PavedDrive      0.00
# MSZoning        0.00
# dtype: float64

# %%
sns.set_style("whitegrid")
missing = categorical_features.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
categorical_features.columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# **Inputs**
#
# 1. Electircal we will replace with Median
#
# 2. Some of House's don't have Basement so fill nan by No Basement in  feature like                                                              #(BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2)
# and similarly for No Garage as well
#
# 3. Fill nan in Continous features related to Basement by 0 because some of House don't have basement.

# %%
# Impute missing values for Electrical
df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)

# Impute missing values for MasVnrType
df["MasVnrType"] = df["MasVnrType"].fillna("None")

df["BsmtQual"] = df["BsmtQual"].fillna("No Basement")
df["BsmtCond"] = df["BsmtCond"].fillna("No Basement")
df["BsmtExposure"] = df["BsmtExposure"].fillna("No Basement")
df["BsmtFinType1"] = df["BsmtFinType1"].fillna("No Basement")
df["BsmtFinType2"] = df["BsmtFinType2"].fillna("No Basement")




# Similarly fill nan in Continous features related to Basement by 0 because some of House don't have basement.
df["BsmtFinSF1"] = df["BsmtFinSF1"].fillna(0)
df["BsmtFinSF2"] = df["BsmtFinSF2"].fillna(0)
df["BsmtUnfSF"] = df["BsmtUnfSF"].fillna(0)
df["TotalBsmtSF"] = df["TotalBsmtSF"].fillna(0)

#Some of House's don't have Garage so fill nan by No Garage in some feature like (GarageType,GarageFinish,GarageCond,GarageQual)

df["GarageType"] = df["GarageType"].fillna("No Garage")
df["GarageFinish"] = df["GarageFinish"].fillna("No Garage")
df["GarageCond"] = df["GarageCond"].fillna("No Garage")
df["GarageQual"] = df["GarageQual"].fillna("No Garage")

# %% [markdown]
# <span style='background:yellow'>**Observation:** As discussed we have imputed the missing values and below we are checking if any more categorical values are yet to be handled </span>

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
# fill na in FireplaceQu feature by No Fireplace
df["FireplaceQu"] = df["FireplaceQu"].fillna("Fireplace Notthere")

# %% [markdown]
# <span style='background:yellow'>**Observation:** we now had kept Fireplace seperately and added the "Fireplace not there", it should not be replaced with median. Each house might or not might not have the Fireplace</span>

# %% [markdown]
# ## Numerical

# %%
numerical_features = df.select_dtypes(include=["float64","int64"])
numerical_features.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0         120          nan     4928            6            5       1976
# 1          20        95.00    15865            8            6       1970
# 2          60        92.00     9920            7            5       1996
# 3          20       105.00    11751            6            6       1977
# 4          20          nan    16635            6            7       1977
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          1976        0.00         120           0        958         1078
# 1          1970        0.00         351         823       1043         2217
# 2          1997        0.00         862           0        255         1117
# 3          1977      480.00         705           0       1139         1844
# 4          2000      126.00        1246           0        356         1602
#
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Seperated as the Numerical Columns </span>

# %%
sns.set_style("whitegrid")
missing = numerical_features.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
numerical_features.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice', 'found'],
#       dtype='object')

# %%
# Impute missing values for MasVnrArea
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)

# In some of house's has no garage than GarageYrBlt should be zero it's continuous feature can't assign no garage.
df["GarageYrBlt"]=df["GarageYrBlt"].fillna(0)



# Impute missing values for LotFrontage
df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace=True)

# %%
<span style='background:yellow'>**Observation:**Missing numercal values were replaced and was checked below.. </span>
# Out:
#   File "<ipython-input-112-4d836d076a18>", line 1
#     <span style='background:yellow'>**Observation:**Missing numercal values were replaced and was checked below.. </span>
#     ^
# SyntaxError: invalid syntax

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %% [markdown]
# **Observation**: Now all the missing values have been filled with required data, and only Sale price has missing values which is expected as Test Set didnt have Saleprice data. Now that we are done with data cleaning, lets move to next stage

# %% [markdown]
# ## Feature Creation

# %%
# Sale Price range from min to max according to year.
plt.figure(figsize=(10,5))
sns.pointplot(df["YrSold"],df["SalePrice"])

# %% [markdown]
# It is seen that 2007 had the highest price for a House sold in all 5 years of Data. it is also seen that 2010 had highest range of Sale's Price.

# %%
# Sale Price range from min to max in every year with Street
plt.figure(figsize=(10,5))
sns.pointplot(df["YrSold"],df["SalePrice"],hue=df["Street"])

# %% [markdown]
# From the above it is seen that Pavel Street Sale Price range is not varying much however the Sale price in Gravel street varies a lot.

# %%
##Create a new column named 'WhetherRemodelled': This column would determine whether the house has been remodelled or not based on 'YearBuilt' anf 'YearRemodAdd' 

def Remodel_Check(row):     ##Based on the difference between remodelled and built years
    if(row['YearBuilt'] == row['YearRemodAdd']):
        return 0     #Indicate not Remodelled
    elif (row['YearBuilt'] < row['YearRemodAdd']):
        return 1     #Indicated Remodelled
    else:
        return 2    #Any other observation check
    
df['WhetherRemodelled'] = df.apply(Remodel_Check, axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL        69.00     4928   Pave      IR1         Lvl
# 1          20       RL        95.00    15865   Pave      IR1         Lvl
# 2          60       RL        92.00     9920   Pave      IR1         Lvl
# 3          20       RL       105.00    11751   Pave      IR1         Lvl
# 4          20       RL        69.00    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %%
##Confirmed: no wrong entries with value '2'. Hence, 0 if not remodelled and 1 if remodelled.
df.WhetherRemodelled.value_counts()
# Out:
# 0    764
# 1    696
# Name: WhetherRemodelled, dtype: int64

# %%
##Derive a new variable named 'AgeofProperty' to determine the age of property since the built

def find_age_since_built(row):
        return row['YrSold'] - row['YearBuilt']
    
df['AgeofProperty'] = df.apply(find_age_since_built, axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL        69.00     4928   Pave      IR1         Lvl
# 1          20       RL        95.00    15865   Pave      IR1         Lvl
# 2          60       RL        92.00     9920   Pave      IR1         Lvl
# 3          20       RL       105.00    11751   Pave      IR1         Lvl
# 4          20       RL        69.00    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %%
##Dropping the raw attributes from which the new features were derived. These aren't necessary for analysis
##Dropping 'YrSold', 'GarageYrBlt', 'YearRemodAdd' and 'YearBuilt'

df = df.drop(['YearBuilt', 'YearRemodAdd', 'YrSold', 'GarageYrBlt'], axis = 1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL        69.00     4928   Pave      IR1         Lvl
# 1          20       RL        95.00    15865   Pave      IR1         Lvl
# 2          60       RL        92.00     9920   Pave      IR1         Lvl
# 3          20       RL       105.00    11751   Pave      IR1         Lvl
# 4          20       RL        69.00    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %%
df.shape
# Out:
# (1460, 75)

# %% [markdown]
# ## Creating Functions (Inspired by similar work)

# %%
##Creating a function for 'categorical_freq_prcnt_plt'
def categorical_freq_prcnt_plt(data,f1,f2,f3):
    if(f3!=0):
        df= data.copy()
        sns.set(style='white')
        plt.figure(figsize=(14, 8), dpi=100)
        
        plt.subplot(131)  #subplot(131)
        ab = pd.DataFrame((df[f1].value_counts(normalize=True)*100).round(0).sort_values())
        ab.reset_index(inplace=True)
        ab1 = sns.barplot(x='index',y=f1, data=ab, palette='Set1')
        
        plt.setp(ab1.get_xticklabels(), rotation=90, horizontalalignment='right')
        plt.xlabel(f1, fontsize= 14, fontstyle='italic')
        plt.ylabel('Frequency(%count of total)', fontsize= 14, fontstyle='italic')
        plt.title(f1+' Analysis', fontsize=16, fontweight='bold')
        plt.grid(True)
        
        for i in ab1.patches:
            ab1.annotate(format(i.get_height())+"%", (i.get_x() + i.get_width() / 2.\
                                                         , i.get_height()), ha = 'center'\
                , va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=45, fontsize=11)
        
        plt.subplot(132)  #subplot(132)
        cn = pd.DataFrame((df[f2].value_counts(normalize=True)*100).round(0).sort_values())
        cn.reset_index(inplace=True)
        ab2 = sns.barplot(x='index',y=f2, data=cn, palette='Set1')
        
        plt.setp(ab2.get_xticklabels(), rotation=90, horizontalalignment='right')
        plt.xlabel(f2, fontsize= 14, fontstyle='italic')
        plt.ylabel('Frequency(%count of total)', fontsize= 14, fontstyle='italic')
        plt.title(f2+' Analysis', fontsize=16, fontweight='bold')
        plt.grid(True)
        
        for i in ab2.patches:
            ab2.annotate(format(i.get_height())+"%", (i.get_x() + i.get_width() / 2.\
                                                         , i.get_height()), ha = 'center'\
                , va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=45, fontsize=11)
        
        plt.subplot(133)  #subplot(133)
        ef = pd.DataFrame((df[f3].value_counts(normalize=True)*100).round(0).sort_values())
        ef.reset_index(inplace=True)
        ab3 = sns.barplot(x='index',y=f3, data=ef, palette='Set1')
        
        plt.setp(ab3.get_xticklabels(), rotation=90, horizontalalignment='right')
        plt.xlabel(f3, fontsize= 14, fontstyle='italic')
        plt.ylabel('Frequency(%count of total)', fontsize= 14, fontstyle='italic')
        plt.title(f3+' Analysis', fontsize=16, fontweight='bold')
        
        for i in ab3.patches:
            ab3.annotate(format(i.get_height())+"%", (i.get_x() + i.get_width() / 2.\
                                                         , i.get_height()), ha = 'center'\
                , va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=45, fontsize=11)
            
        plt.grid(True)
        plt.tight_layout()
        plt.autoscale()
        plt.show()
    else:
        df= data.copy()
        sns.set(style='white')
        plt.figure(figsize=(14, 8), dpi=100)
        
        plt.subplot(121)  #subplot(121)
        ab = pd.DataFrame((df[f1].value_counts(normalize=True)*100).round(0).sort_values())
        ab.reset_index(inplace=True)
        ab1 = sns.barplot(x='index',y=f1, data=ab, palette='Set1')
        
        plt.setp(ab1.get_xticklabels(), rotation=90, horizontalalignment='right')
        plt.xlabel(f1, fontsize= 14, fontstyle='italic')
        plt.ylabel('Frequency(%count of total)', fontsize= 14, fontstyle='italic')
        plt.title(f1+' Analysis', fontsize=16, fontweight='bold')
        plt.grid(True)
        
        for i in ab1.patches:
            ab1.annotate(format(i.get_height())+"%", (i.get_x() + i.get_width() / 2.\
                                                         , i.get_height()), ha = 'center'\
                , va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=45, fontsize=11)
        
        plt.subplot(122)  #subplot(122)
        cn = pd.DataFrame((df[f2].value_counts(normalize=True)*100).round(0).sort_values())
        cn.reset_index(inplace=True)
        ab2 = sns.barplot(x='index',y=f2, data=cn, palette='Set1')
        
        plt.setp(ab2.get_xticklabels(), rotation=90, horizontalalignment='right')
        plt.xlabel(f2, fontsize= 14, fontstyle='italic')
        plt.ylabel('Frequency(%count of total)', fontsize= 14, fontstyle='italic')
        plt.title(f2+' Analysis', fontsize=16, fontweight='bold')
        
        for i in ab2.patches:
            ab2.annotate(format(i.get_height())+"%", (i.get_x() + i.get_width() / 2.\
                                                         , i.get_height()), ha = 'center'\
                , va = 'center', xytext = (0, 10), textcoords = 'offset points',rotation=45, fontsize=11)
        
        plt.grid(True)
        plt.tight_layout()
        plt.autoscale()
        plt.show()

# %% [markdown]
# # EDA

# %% [markdown]
# ## Bi-Variate Analysis

# %%
categorical_freq_prcnt_plt(df,'MSZoning','LotShape','LotConfig')
categorical_freq_prcnt_plt(df,'KitchenQual', 'FireplaceQu','RoofStyle')
categorical_freq_prcnt_plt(df,'GarageType', 'GarageFinish', 'MasVnrType')
categorical_freq_prcnt_plt(df,'ExterQual','Foundation', 'BsmtQual')
categorical_freq_prcnt_plt(df,'BsmtExposure', 'BsmtFinType1', 'HeatingQC')
categorical_freq_prcnt_plt(df, 'Neighborhood', 'HouseStyle',0)
categorical_freq_prcnt_plt(df,'Exterior1st', 'Exterior2nd', 0)

# %% [raw]
# Observations
# Most preferred choices:
# 1. (MSZoning) zone of the sale:'RL'(Residential Low Density) followed by 'RM'(Residential Medium Density) with high frequency
# 2. LotShape analysis shows Reg(Regular) type followed by IR1 with high frequency
# 3. LotConfig analysis displays Inside(Inside lot) followed by Corner with high frequency
# 4. No significant preference seen with respect to,
#  4.a FireplaceQuality and MasVnrType
#  4.b KitchenQuality, ExterQual (Quality of exterior material), BsmtQual (Height of basement):'TA'(Typical/Average)
# 5. RoofStyle analysis shows 'Gable' with highest frequency
# 6. Under Garage, Attached Garage type is the preferred model as well.
# 7. Under GarageFinish, Unfinished garage has highest frequency count
# 8. Foundation shows, Poured Concrete as preferred option
# 9. (BsmtFinType1) Rating of Basement Fin. Area shows Good Living Quarters and Unfinished with high frequency
# 10. HeatingQC has Excellent as prefrence
# 11. Neighborhood prefrences are seen as North Ames, followed by College Creek
# 12. HouseStyle preferred is One storey, followed by Two storey.
# 13. Exterior1st ie Exterior covering on the house and Exterior2nd ie if more than one material on exterior preference would be Vinyl Siding, followed by Metal Siding
# 14. Basement Exposure preference is No Exposure

# %%
##Numeric cateogorical variables
numeric_cat_cols = ['MSSubClass','MoSold','OverallQual','OverallCond','BsmtFullBath','FullBath','HalfBath','BedroomAbvGr',\
                    'TotRmsAbvGrd','Fireplaces','GarageCars','WhetherRemodelled']

# %%
categorical_freq_prcnt_plt(df, 'MoSold', 'MSSubClass',0)
categorical_freq_prcnt_plt(df, 'OverallQual','OverallCond','BsmtFullBath')
categorical_freq_prcnt_plt(df, 'FullBath','HalfBath','BedroomAbvGr')
categorical_freq_prcnt_plt(df, 'TotRmsAbvGrd','Fireplaces',0)
categorical_freq_prcnt_plt(df, 'GarageCars','WhetherRemodelled',0)

# %% [raw]
# Observations
# Most preferred choices are listed below
# 1. Month (House) Sold: June has the high count followed by July and May
# 2. Most preferred type of dwelling in MSSubClass is 20 i.e. 1-Story 1946 & Newer All Styles, followed by 60 i.e. 2-Story 1946 & Newer.
# 3. Most houses fall under Average and Above average wrt Overall Quality (material and finish)
# 4. Likewise all houses fall under Mostly Average followed by Above average when we look at Overall Condition
# 5. a. Basement Full Bathrooms shows Maximum 0(None), followed by 1 as highest
#    b. Full Bathrooms shows Preferred 2, followed by 1 and
#    c. Half Bathrooms shows Preferred 0(None), followed by 1.
# 6. Bedrooms Above Ground shows 3, followed by 2.
# 7. Total Rooms Above Ground is seen as 6, followed by 7.
# 8. No significant preferences is seen for  for Fireplaces (either 0 or 1) and WhetherRemodelled (House) or not.
# 9. GarageCars space shows 2 car spaces, followed by 1 car space as highest

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Correlation matrix/heatmap

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Correlation with target variable-Numerical + Plot

# %%
corr_matrix = df.corr()
corr_matrix["SalePrice"].sort_values(ascending=True)
# Out:
# AgeofProperty       -0.52
# KitchenAbvGr        -0.13
# EnclosedPorch       -0.12
# OverallCond         -0.07
# MSSubClass          -0.06
# LowQualFinSF        -0.03
# MiscVal             -0.01
# WhetherRemodelled   -0.01
# BsmtHalfBath        -0.01
# BsmtFinSF2          -0.01
# 3SsnPorch            0.06
# MoSold               0.07
# ScreenPorch          0.10
# PoolArea             0.10
# BedroomAbvGr         0.16
# BsmtFullBath         0.21
# BsmtUnfSF            0.22
# LotArea              0.25
# HalfBath             0.30
# WoodDeckSF           0.32
# LotFrontage          0.32
# 2ndFlrSF             0.33
# OpenPorchSF          0.34
# BsmtFinSF1           0.36
# Fireplaces           0.46
# MasVnrArea           0.46
# TotRmsAbvGrd         0.53
# FullBath             0.55
# 1stFlrSF             0.59
# TotalBsmtSF          0.60
# GarageArea           0.62
# GarageCars           0.63
# GrLivArea            0.71
# OverallQual          0.79
# SalePrice            1.00
# ...

# %%
plt.figure(figsize=(22,7))
df.corr()['SalePrice'].sort_values(ascending=False).drop(['SalePrice']).plot(kind="bar",color='c')
plt.xlabel("SalePrice",fontsize=14)
plt.ylabel("Column with target names",fontsize=14)
plt.title("Correlation with target",fontsize=14)
plt.show()

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have seen the correlation with the target variable with highly positive and negative values. We have seen in a table and chart format</span>

# %% [markdown]
# # Outliers

# %%
##Check outliers
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.95,0.98,0.99,1])
# Out:
#        MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# count     1460.00      1460.00   1460.00      1460.00      1460.00
# mean        56.90        69.86  10516.83         6.10         5.58
# std         42.30        22.03   9981.26         1.38         1.11
# min         20.00        21.00   1300.00         1.00         1.00
# 10%         20.00        49.00   5000.00         5.00         5.00
# 25%         20.00        60.00   7553.50         5.00         5.00
# 50%         50.00        69.00   9478.50         6.00         5.00
# 75%         70.00        79.00  11601.50         7.00         6.00
# 95%        160.00       104.00  17401.15         8.00         8.00
# 98%        188.20       120.82  25251.62         9.00         8.00
# 99%        190.00       137.41  37567.64        10.00         9.00
# 100%       190.00       313.00 215245.00        10.00         9.00
# max        190.00       313.00 215245.00        10.00         9.00
#
# ...

# %%
# Check the outliers in all the numeric columns (boxplot)

plt.figure(figsize=(20, 20))
plt.subplot(5,3,1)
sns.boxplot(y = 'LotArea', color='b', data = df)
plt.subplot(5,3,2)
sns.boxplot(y = 'TotalBsmtSF', color='b', data = df)
plt.subplot(5,3,3)
sns.boxplot(y = 'MasVnrArea', color='b', data = df)
plt.subplot(5,3,4)
sns.boxplot(y = 'OpenPorchSF', color='b', data = df)
plt.subplot(5,3,5)
sns.boxplot(y = 'WoodDeckSF', color='b', data = df)
plt.subplot(5,3,6)
sns.boxplot(y = 'GrLivArea', color='b', data = df)


plt.show()

# %%
df.shape
# Out:
# (1460, 75)

# %%
##Removing the Outliers
# Removing values beyond 98% for LotArea

q_LotArea = df['LotArea'].quantile(0.98)
df = df[df["LotArea"] < q_LotArea]


# Removing values beyond 99% for TotalBsmtSF
q_TotalBsmtSF = df['TotalBsmtSF'].quantile(0.99)
df = df[df["TotalBsmtSF"] < q_TotalBsmtSF]

# Removing values beyond 99% for WoodDeckSF

q_WoodDeckSF = df['WoodDeckSF'].quantile(0.99)
df = df[df["WoodDeckSF"] < q_WoodDeckSF]

# Removing values beyond 99% for OpenPorchSF

q_OpenPorchSF = df['OpenPorchSF'].quantile(0.99)
df = df[df["OpenPorchSF"] < q_OpenPorchSF]

# %%
##Check shape of the dataset
total_records= df.shape[0]  #storing total no. of records in a variable
df.shape
# Out:
# (1386, 75)

# %%
# Determine the percentage of data retained

retained_data = round(100*(len(df)/total_records),2)
print(retained_data,"%")
# Out:
# 100.0 %

# %% [markdown]
# # Skewness Handling

# %%
##Removing numeric attributes that have more than 80% data associated to one single value.

def get_num_cols_imbal(data, prcnt):
    df1= df.copy()
    my_list= []
    num_cols = df1.select_dtypes(include=['int64','float64','int32','float32'])
    for col in (num_cols):
        if(df1[col].value_counts().max() > int(prcnt*len(df1.index)/100)):
            my_list.append(col)
    return my_list

##Removing the skewed data
num_cols_to_be_removed = get_num_cols_imbal(data=df, prcnt=80)  
print("Numeric columns removed:",num_cols_to_be_removed)
print("\nNumber of numeric columns removed: ", len(num_cols_to_be_removed),"\n")
# Out:
# Numeric columns removed: ['BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', 'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'found']
#
# Number of numeric columns removed:  10

# %%
##Dropping columns with skewed data (int and float type numeric variables)
df = df.drop(['BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', 'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal'], axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL        69.00     4928   Pave      IR1         Lvl
# 2          60       RL        92.00     9920   Pave      IR1         Lvl
# 3          20       RL       105.00    11751   Pave      IR1         Lvl
# 4          20       RL        69.00    16635   Pave      IR1         Lvl
# 5          60       RL        58.00    14054   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
# 5    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
#
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Outliers and skewness has been handled. Now lets move to Label Encoding </span>

# %% [markdown]
# # Label Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1386 entries, 0 to 291
# Data columns (total 66 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSSubClass         1386 non-null   int64
#  1   MSZoning           1386 non-null   object
#  2   LotFrontage        1386 non-null   float64
#  3   LotArea            1386 non-null   int64
#  4   Street             1386 non-null   object
#  5   LotShape           1386 non-null   object
#  6   LandContour        1386 non-null   object
#  7   Utilities          1386 non-null   object
#  8   LotConfig          1386 non-null   object
#  9   LandSlope          1386 non-null   object
#  10  Neighborhood       1386 non-null   object
#  11  Condition1         1386 non-null   object
#  12  Condition2         1386 non-null   object
#  13  BldgType           1386 non-null   object
#  14  HouseStyle         1386 non-null   object
#  15  OverallQual        1386 non-null   int64
# ...

# %%
categorical = df.select_dtypes(include = ["object"]).keys()
categorical
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
le = LabelEncoder()
for column in categorical:
    df.loc[:,column]=le.fit_transform(df.loc[:,column])
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0         120         3        69.00     4928       1         0            3
# 2          60         3        92.00     9920       1         0            3
# 3          20         3       105.00    11751       1         0            3
# 4          20         3        69.00    16635       1         0            3
# 5          60         3        58.00    14054       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            13           2           2
# 2          0          1          0            15           2           2
# 3          0          4          0            14           2           2
# 4          0          2          0            14           2           2
# 5          0          4          0             8           2           2
#
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have seperated all the categorical columns and then have done the Label Encoding for all the columns. Below we are checking if there are any missing values. As expected only Sale Price has missing columns and we are good to move to Model Building </span>

# %%
df.isnull().sum()
# Out:
# MSSubClass             0
# MSZoning               0
# LotFrontage            0
# LotArea                0
# Street                 0
# LotShape               0
# LandContour            0
# Utilities              0
# LotConfig              0
# LandSlope              0
# Neighborhood           0
# Condition1             0
# Condition2             0
# BldgType               0
# HouseStyle             0
# OverallQual            0
# OverallCond            0
# RoofStyle              0
# RoofMatl               0
# Exterior1st            0
# Exterior2nd            0
# MasVnrType             0
# MasVnrArea             0
# ExterQual              0
# ExterCond              0
# Foundation             0
# BsmtQual               0
# BsmtCond               0
# BsmtExposure           0
# BsmtFinType1           0
# BsmtFinSF1             0
# BsmtFinType2           0
# BsmtUnfSF              0
# TotalBsmtSF            0
# Heating                0
# HeatingQC              0
# CentralAir             0
# ...

# %% [markdown]
# # Model Building-Regression

# %% [markdown]
# ## Importing Libraries for Model Building (Regression)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score ,mean_absolute_error,mean_squared_error
from sklearn.metrics import mean_squared_log_error
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.ensemble import BaggingRegressor

# %%
df["found"].value_counts()
# Out:
# 1    1109
# 2     277
# Name: found, dtype: int64

# %%
#Lets seprate the train and test
df_train1=df.loc[df["found"]==1]
df_test1=df.loc[df["found"]==2]
df_train1.reset_index(drop=True,inplace=True)
df_test1.reset_index(drop=True,inplace=True)

# %%
df_train1.head(2)
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0         120         3        69.00     4928       1         0            3
# 1          60         3        92.00     9920       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            13           2           2
# 1          0          1          0            15           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 0         4           2            6            5          1         0
# 1         0           5            7            5          1         0
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0            9           10           2        0.00          3          4
# 1            8            8           2        0.00          2          4
#
# ...

# %%
df_test1.head(2)
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          20         3        86.00    14157       1         0            1
# 1         120         3        69.00     5814       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          0          0            22           2           2
# 1          0          1          0            22           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 0         0           2            9            5          3         0
# 1         4           2            8            5          1         0
#
#    Exterior1st  Exterior2nd  MasVnrType  MasVnrArea  ExterQual  ExterCond  \
# 0           12           13           3      200.00          2          4
# 1            6            6           2        0.00          2          4
#
# ...

# %%
#Lets drop the target variable from test dataset as that is the o/p variable that needs to be predicted

# %%
df_test1.drop(columns=["SalePrice"],inplace=True)

# %%
#lets drop source column from df_train and df_test
df_train1.drop(columns=["found"],inplace=True)
df_test1.drop(columns=["found"],inplace=True)

# %%
#seprating input and output from df_train
df_x=df_train1.drop(columns=["SalePrice"])
y=df_train1[["SalePrice"]]

# %% [markdown]
# # Standard Scalar on Train Data

# %%
#Lets bring every column to common scale
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0        1.51     -0.02        -0.03    -1.26    0.05     -1.41         0.31
# 1        0.07     -0.02         1.15     0.11    0.05     -1.41         0.31
# 2       -0.89     -0.02         1.81     0.61    0.05     -1.41         0.31
# 3       -0.89     -0.02        -0.03     1.95    0.05     -1.41         0.31
# 4        0.07     -0.02        -0.60     1.24    0.05     -1.41         0.31
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0       0.00       0.60      -0.21          0.15       -0.03       -0.00
# 1       0.00      -1.24      -0.21          0.48       -0.03       -0.00
# 2       0.00       0.60      -0.21          0.31       -0.03       -0.00
# 3       0.00      -0.63      -0.21          0.31       -0.03       -0.00
# 4       0.00       0.60      -0.21         -0.69       -0.03       -0.00
#
# ...

# %% [markdown]
# ## Train & Test Split

# %% [markdown]
# ## Finding Best Random State

# %%
maxAccu=0
BestRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)    
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        BestRs=i
print("Best accuracy is ", maxAccu,"on Random_state  ",BestRs)
# Out:
# Best accuracy is  0.9221901070167301 on Random_state   162

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=BestRs)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (887, 64)
# (222, 64)
# (887, 1)
# (222, 1)

# %% [markdown]
# ## Instantiating the Algos

# %%
lm=LinearRegression()
ridge = Ridge()
gb= GradientBoostingRegressor()
dt  = DecisionTreeRegressor()
rf  = RandomForestRegressor()
knn = KNeighborsRegressor()
ls=Lasso()
svr=SVR()

# %% [markdown]
# ## Building the Model & Evaluation Metrics

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x,y,modelList):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    modelCrossval1=[]
    RMSECVDiff=[]
    
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(x_train,y_train)
        pred=modelInstance.predict(x_test)
        error=modelInstance.score(x_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x,y,cv=5,scoring='r2').mean()
        crossAcc1=cross_val_score(modelInstance,x,y,cv=5,scoring='neg_root_mean_squared_error').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(r2-crossAcc)
        modelCrossval1.append(crossAcc1)
        RMSECVDiff.append(RMSE-crossAcc1)
        
    df_acc=pd.DataFrame({"Name":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "R2CVDiff":R2CVDiff,
                         "RMSECVDiff":RMSECVDiff
                          })
    return df_acc
GetAccuracy(x,y,modelList)
# Out:
#              Name  Error   R2      MAE           MSE     RMSE  \
# 0         Lin Reg   0.89 0.91 15490.66  442037800.84 21024.70
# 1           Lasso   0.89 0.91 15440.99  441233151.09 21005.55
# 2           Ridge   0.89 0.91 15417.64  440776617.87 20994.68
# 3  Gradient boost   0.97 0.91 14517.51  447703819.47 21159.01
# 4   Decision Tree   1.00 0.74 26439.11 1301754959.11 36079.84
# 5   Random Forest   0.98 0.91 15054.07  444259198.24 21077.46
# 6        Kneigbor   0.87 0.85 19392.37  747645202.25 27343.10
#
#    CrossValidation  R2CVDiff  RMSECVDiff
# 0             0.87      0.04    46431.81
# 1             0.87      0.04    46399.28
# 2             0.87      0.04    46340.55
# 3             0.88      0.03    45041.39
# 4             0.72      0.02    72605.74
# 5             0.87      0.04    45806.99
# 6             0.80      0.05    58679.08

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have used 7 Algos and used 6 Evaluation metrics. Now lets use R2 as our scoring model and so the same in Cross validation, we will use R2. now if we see the diff between R2 and CV is lowest for Decision Tree. However the R2 score & CV score is not very low. So lets move to next lowest, which is Gradient boost. So Gradient Boost will be our top choice. Also lets check the others, our next best diff is 0.04, which is with couple of Algos, like Linear, Lasso, Ridge and Random Forest. We have too many columns and using Linear is a very simple algo, so lets use PCA to see if our score increases and also use the top 3 Algos in Hyper Parameter Tuning </span>

# %% [markdown]
# # PCA

# %%
#Lets use pca to reduce the dimensionality
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
x_pca=pca.fit_transform(x)
print("variance :{}".format(np.sum(pca.explained_variance_ratio_)))
# Out:
# variance :0.48831331613723544

# %% [markdown]
# ## PCA Model Building

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x_pca,y,modelList):
    p_train,p_test,y_train,y_test=train_test_split(x_pca,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    modelCrossval1=[]
    RMSECVDiff=[]
    
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(p_train,y_train)
        pred=modelInstance.predict(p_test)
        error=modelInstance.score(p_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x,y,cv=5,scoring='r2').mean()
        crossAcc1=cross_val_score(modelInstance,x,y,cv=5,scoring='neg_root_mean_squared_error').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(r2-crossAcc)
        modelCrossval1.append(crossAcc1)
        RMSECVDiff.append(RMSE-crossAcc1)
        
    df_acc=pd.DataFrame({"PCAName":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "R2CVDiff":R2CVDiff,
                         "RMSECVDiff":RMSECVDiff
                          })
    return df_acc
GetAccuracy(x_pca,y,modelList)
# Out:
#           PCAName  Error   R2      MAE           MSE     RMSE  \
# 0         Lin Reg   0.85 0.88 17802.64  587316314.49 24234.61
# 1           Lasso   0.85 0.88 17802.66  587325046.23 24234.79
# 2           Ridge   0.85 0.88 17801.56  587319474.51 24234.68
# 3  Gradient boost   0.96 0.89 15821.28  536276744.78 23157.65
# 4   Decision Tree   1.00 0.78 23965.97 1079506914.36 32855.85
# 5   Random Forest   0.98 0.89 16401.54  566713886.41 23805.75
# 6        Kneigbor   0.89 0.86 18015.94  673964789.87 25960.83
#
#    CrossValidation  R2CVDiff  RMSECVDiff
# 0             0.87      0.01    49641.73
# 1             0.87      0.01    49628.52
# 2             0.87      0.01    49580.54
# 3             0.88      0.01    47138.77
# 4             0.73      0.05    69758.64
# 5             0.87      0.01    48784.73
# 6             0.80      0.06    57296.81

# %% [markdown]
# <span style='background:yellow'>**Observation:**R2 Scores of PCA are lower than non-PCA. So lets skip PCA model </span>

# %% [markdown]
# # HyperParameter Tuning

# %% [markdown]
# ## Gradient Boost Regressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
                "min_samples_split": range(6, 11)}

# %%
GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'min_samples_split': range(6, 11)})

# %%
GCV.best_params_
# Out:
# {'min_samples_split': 6}

# %%
mod=GradientBoostingRegressor(min_samples_split=8)           
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(cross_val_score(mod,x,y,scoring='r2').mean())
# Out:
# 0.8834567336747898

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have got 88% with Gradient Boost, lets use with other Algos and check </span>

# %% [markdown]
# ## Random Forest Regressor

# %%
parameters ={
              "n_estimators":[10,100,500]
             }

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [10, 100, 500]})

# %%
GCV.best_params_
# Out:
# {'n_estimators': 500}

# %%
mod3=RandomForestRegressor(n_estimators= 500)
mod3.fit(x_train,y_train)
pred=mod3.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9315675324202386

# %% [markdown]
# # Regression Forest with multiple parameters

# %%
parameters ={  
                            "bootstrap": [True,False],
                          }

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False]})

# %%
GCV.best_params_
# Out:
# {'bootstrap': True}

# %%
mod=RandomForestRegressor(bootstrap= True)
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9309663656653114

# %%
mod=RandomForestRegressor(bootstrap= True, criterion='mse',max_depth=5,min_samples_leaf = 1, min_samples_split =6)
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9057712510661294

# %%
mod1=RandomForestRegressor()
mod1.fit(x_train,y_train)
pred=mod1.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9344170595844354

# %%
parameters ={
              "bootstrap": [True,False],
              "criterion" : ["mse", "mae"],
             }

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['mse', 'mae']})

# %%
GCV.best_params_
# Out:
# {'bootstrap': True, 'criterion': 'mse'}

# %%
mod=RandomForestRegressor(bootstrap= True, criterion='mse')
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.9328520465684043

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have used multiple parameters in RandomForest Regressor. We have improved our score from 91% to 93%. It is a very good improvement. We will use the same to Save the model and share to Biz  </span>

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(mod,"housingproject.pkl")
# Out:
# ['housingproject.pkl']

# %% [markdown]
# # Loading the Model

# %%
model=joblib.load("housingproject.pkl")

# %%
prediction=model.predict(x_test)

# %%
print(r2_score(y_test,pred))
# Out:
# 0.9328520465684043

# %%
prediction=pd.DataFrame(prediction) #converting to a Data Frame

# %%
prediction.head()  #checking the top 5 values, to double check fi there are predictions
# Out:
#           0
# 0 180206.58
# 1 141723.00
# 2  83822.59
# 3 172451.92
# 4 119766.10

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have saved the model which has 93% R2score. The same was loaded to check and it is working fine. We are happy to share with Biz our model </span>
