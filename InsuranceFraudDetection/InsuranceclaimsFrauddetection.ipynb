# %% [markdown]
# ![InsuranceFraud.png](attachment:InsuranceFraud.png)

# %% [markdown]
# # Insurance Claims Fraud Detection-  Python Machine Learning

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Insurance-Claims-Fraud-Detection---Python-Machine-Learning" data-toc-modified-id="Insurance-Claims-Fraud-Detection---Python-Machine-Learning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Insurance Claims Fraud Detection-  Python Machine Learning</a></span></li><li><span><a href="#Problem-Statement-(Given)" data-toc-modified-id="Problem-Statement-(Given)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Problem Statement (Given)</a></span></li><li><span><a href="#Choosing-the-Right-Tools" data-toc-modified-id="Choosing-the-Right-Tools-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Choosing the Right Tools</a></span><ul class="toc-item"><li><span><a href="#Importing-and-Installing-Right-Packages" data-toc-modified-id="Importing-and-Installing-Right-Packages-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Importing and Installing Right Packages</a></span></li><li><span><a href="#Handling-Warnings" data-toc-modified-id="Handling-Warnings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Handling Warnings</a></span></li></ul></li><li><span><a href="#Loading-Dataset" data-toc-modified-id="Loading-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Loading Dataset</a></span></li><li><span><a href="#Initial-Analysis-of-Data" data-toc-modified-id="Initial-Analysis-of-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Initial Analysis of Data</a></span></li><li><span><a href="#Data-Pre-Processing" data-toc-modified-id="Data-Pre-Processing-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Pre-Processing</a></span></li><li><span><a href="#Dropping-Columns" data-toc-modified-id="Dropping-Columns-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Dropping Columns</a></span><ul class="toc-item"><li><span><a href="#Dropping-Column-&quot;_c39&quot;-as-it-has-no-values-in-it" data-toc-modified-id="Dropping-Column-&quot;_c39&quot;-as-it-has-no-values-in-it-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Dropping Column "_c39" as it has no values in it</a></span></li><li><span><a href="#Dropping-columns-which-have-900+-unique-values" data-toc-modified-id="Dropping-columns-which-have-900+-unique-values-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Dropping columns which have 900+ unique values</a></span></li><li><span><a href="#Dropping-Column-&quot;Total-Claim-amount&quot;-as-it-is-a-total-'injury_claim',-'property_claim'-and-'vehicle_claim'" data-toc-modified-id="Dropping-Column-&quot;Total-Claim-amount&quot;-as-it-is-a-total-'injury_claim',-'property_claim'-and-'vehicle_claim'-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Dropping Column "Total Claim amount" as it is a total 'injury_claim', 'property_claim' and 'vehicle_claim'</a></span></li></ul></li><li><span><a href="#Removing-non-numeric-data" data-toc-modified-id="Removing-non-numeric-data-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Removing non-numeric data</a></span><ul class="toc-item"><li><span><a href="#Replacing-&quot;?&quot;-with-Unknown-in-&quot;collision_type&quot;,-&quot;property_damange-&amp;-&quot;police_report_available&quot;-column" data-toc-modified-id="Replacing-&quot;?&quot;-with-Unknown-in-&quot;collision_type&quot;,-&quot;property_damange-&amp;-&quot;police_report_available&quot;-column-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Replacing "?" with Unknown in "collision_type", "property_damange &amp; "police_report_available" column</a></span></li><li><span><a href="#Object-to-DateTime" data-toc-modified-id="Object-to-DateTime-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Object to DateTime</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bi-Variate-Analysis" data-toc-modified-id="Bi-Variate-Analysis-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Bi-Variate Analysis</a></span></li></ul></li><li><span><a href="#Label-Encoding-Target-Variable" data-toc-modified-id="Label-Encoding-Target-Variable-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Label Encoding Target Variable</a></span><ul class="toc-item"><li><span><a href="#Ordinal-Encoding" data-toc-modified-id="Ordinal-Encoding-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Ordinal Encoding</a></span></li><li><span><a href="#Multivariate-Analysis" data-toc-modified-id="Multivariate-Analysis-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Multivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Correlation-matrix/heatmap" data-toc-modified-id="Correlation-matrix/heatmap-10.2.1"><span class="toc-item-num">10.2.1&nbsp;&nbsp;</span>Correlation matrix/heatmap</a></span></li></ul></li><li><span><a href="#Correlation-with-target-variable-Numerical-+-Plot" data-toc-modified-id="Correlation-with-target-variable-Numerical-+-Plot-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Correlation with target variable-Numerical + Plot</a></span></li></ul></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Skewness" data-toc-modified-id="Skewness-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Skewness</a></span></li><li><span><a href="#Model-Building-(Classification)" data-toc-modified-id="Model-Building-(Classification)-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Model Building (Classification)</a></span></li><li><span><a href="#Importing-Libraries-for-Model-Building-(Classification)" data-toc-modified-id="Importing-Libraries-for-Model-Building-(Classification)-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Importing Libraries for Model Building (Classification)</a></span><ul class="toc-item"><li><span><a href="#Train-&amp;-Test-Data" data-toc-modified-id="Train-&amp;-Test-Data-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Train &amp; Test Data</a></span></li></ul></li><li><span><a href="#Standard-Scalar" data-toc-modified-id="Standard-Scalar-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Standard Scalar</a></span><ul class="toc-item"><li><span><a href="#Over-Sampling" data-toc-modified-id="Over-Sampling-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>Over Sampling</a></span></li><li><span><a href="#Best-Random-State" data-toc-modified-id="Best-Random-State-15.2"><span class="toc-item-num">15.2&nbsp;&nbsp;</span>Best Random State</a></span></li><li><span><a href="#Instantiating-the-Models" data-toc-modified-id="Instantiating-the-Models-15.3"><span class="toc-item-num">15.3&nbsp;&nbsp;</span>Instantiating the Models</a></span></li><li><span><a href="#Model-Building-and-checking-Evaluation-Scores" data-toc-modified-id="Model-Building-and-checking-Evaluation-Scores-15.4"><span class="toc-item-num">15.4&nbsp;&nbsp;</span>Model Building and checking Evaluation Scores</a></span></li></ul></li><li><span><a href="#Model-Building-and-checking-the-Evaluation-Scores" data-toc-modified-id="Model-Building-and-checking-the-Evaluation-Scores-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Model Building and checking the Evaluation Scores</a></span></li><li><span><a href="#AUC-ROC" data-toc-modified-id="AUC-ROC-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>AUC ROC</a></span></li><li><span><a href="#HyperParameter-Tuning" data-toc-modified-id="HyperParameter-Tuning-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>HyperParameter Tuning</a></span></li><li><span><a href="#Saving-the-Model" data-toc-modified-id="Saving-the-Model-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Saving the Model</a></span></li><li><span><a href="#Loading-the-Model" data-toc-modified-id="Loading-the-Model-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Loading the Model</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Summary</a></span></li></ul></div>

# %% [markdown]
# # Problem Statement (Given)

# %% [markdown]
# Insurance Claims- Fraud Detection
# Problem Statement:
# Business case:
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
#
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
#
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %% [markdown]
# # Choosing the Right Tools

# %% [markdown]
# ## Importing and Installing Right Packages

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)       # To display all the data in each column
pd.set_option('display.precision', 5)               # To display values only upto three decimal places.
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()
pd.options.display.float_format = '{:.2f}'.format  
import numpy as np
import seaborn as sns
sns.set(style='whitegrid', font_scale = 1.3, color_codes=True)
from sklearn.preprocessing import LabelEncoder


import matplotlib.pyplot as plt
# %matplotlib inline


import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Handling Warnings

# %%
warnings.filterwarnings('ignore') # ignore warnings.
# %config IPCompleter.greedy = True # autocomplete feature.
pd.options.display.max_rows = None # set maximum rows that can be displayed in notebook.
pd.options.display.max_columns = None # set maximum columns that can be displayed in notebook.
pd.options.display.precision = 4 # set the precision of floating point numbers.

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv")

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** The dataset is loaded properly. We see some "?" which needs to be removed.Will be an interesting EDA Also the last columnn "_c39" has no content.   </span>

# %% [markdown]
# # Initial Analysis of Data

# %%
df.shape
# Out:
# (1000, 40)

# %% [markdown]
# <span style='background:yellow'>**Observation:**  A nice round of number of 1000 rows of data and 40 columns </span>

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
duplicates = df[df.duplicated()]
print('There are {} duplicates out of total {} rows'.format(duplicates.shape[0], df.shape[0]))
# Out:
# There are 0 duplicates out of total 1000 rows

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** There are some columns which have unique values of 900+, we can delete these columns, as they wont add any info to our data. Also _c39 has 0 values, so we will drop it as well  </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We see some object columns as date, we need to convert them to date format to use it futher   </span>

# %%
df["fraud_reported"].value_counts()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
df.fraud_reported.value_counts(normalize=True)
# Out:
# N   0.75
# Y   0.25
# Name: fraud_reported, dtype: float64

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have an imbalanced dataset with 25% of the data having fraud detected. We would need to balance the data before model building   </span>

# %%
df.describe()
# Out:
#        months_as_customer     age  policy_number  policy_deductable  \
# count             1000.00 1000.00        1000.00            1000.00
# mean               203.95   38.95      546238.65            1136.00
# std                115.11    9.14      257063.01             611.86
# min                  0.00   19.00      100804.00             500.00
# 25%                115.75   32.00      335980.25             500.00
# 50%                199.50   38.00      533135.00            1000.00
# 75%                276.25   44.00      759099.75            2000.00
# max                479.00   64.00      999435.00            2000.00
#
#        policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# count                1000.00         1000.00      1000.00        1000.00
# mean                 1256.41      1101000.00    501214.49       25126.10
# std                   244.17      2297406.60     71701.61       27872.19
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** Capital gains and capitals loss data is almost opposite to each other as expected.lets get to EDA to understand them more   </span>

# %%
df.select_dtypes(['object','bool']).apply(lambda x: x.value_counts()).T.stack()
# Out:
# policy_bind_date         01-01-2006                   3.00
#                          01-01-2008                   1.00
#                          01-02-1990                   1.00
#                          01-02-1998                   1.00
#                          01-02-2011                   1.00
#                          01-03-1991                   1.00
#                          01-03-1997                   1.00
#                          01-03-2002                   1.00
#                          01-03-2010                   1.00
#                          01-03-2012                   1.00
#                          01-04-1994                   1.00
#                          01-04-2002                   1.00
#                          01-05-1997                   1.00
#                          01-05-1999                   1.00
#                          01-05-2010                   1.00
#                          01-05-2013                   1.00
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We checked for non numeric data, and see ? in our data, which needs to be removed   </span>

# %% [markdown]
# # Data Pre-Processing

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
categorical = df.select_dtypes(include = ["object"]).keys()
categorical
# Out:
# Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %%
Numerical = df.select_dtypes(include = ["int64"]).keys()
Numerical
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_year'],
#       dtype='object')

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have got our column names and seperated them into categorical and numerical to use them as needed.   </span>

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# ...

# %% [markdown]
# # Dropping Columns

# %% [markdown]
# ## Dropping Column "_c39" as it has no values in it

# %%
df["_c39"].value_counts()
# Out:
# Series([], Name: _c39, dtype: int64)

# %%
df.drop(columns=["_c39"],inplace=True)

# %% [markdown]
# ## Dropping columns which have 900+ unique values

# %%
df.drop(columns=["policy_number"],inplace=True)

# %%
df.drop(columns=["policy_bind_date"],inplace=True)

# %%
df.drop(columns=["policy_annual_premium"],inplace=True)

# %%
df.drop(columns=["insured_zip"],inplace=True)

# %%
df.drop(columns=["incident_location"],inplace=True)

# %% [markdown]
# ## Dropping Column "Total Claim amount" as it is a total 'injury_claim', 'property_claim' and 'vehicle_claim'

# %%
df.drop(columns=["total_claim_amount"],inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'injury_claim', 'property_claim',
#        'vehicle_claim', 'auto_make', 'auto_model', 'auto_year',
#        'fraud_reported'],
#       dtype='object')

# %% [markdown]
# <span style='background:yellow'>**Observation:** All the columns that we have deleted, has been dropped and we confirmed with the list of column names    </span>

# %% [markdown]
# # Removing non-numeric data

# %% [markdown]
# ## Replacing "?" with Unknown in "collision_type", "property_damange & "police_report_available" column

# %%
df["collision_type"].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %%
df["collision_type"]=df["collision_type"].str.replace("?","Unknown")

# %%
df["collision_type"].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# Unknown            178
# Name: collision_type, dtype: int64

# %%
df["property_damage"].value_counts()
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %%
df["property_damage"]=df["property_damage"].str.replace("?","Unknown")

# %%
df["property_damage"].value_counts()
# Out:
# Unknown    360
# NO         338
# YES        302
# Name: property_damage, dtype: int64

# %%
df["police_report_available"].value_counts()
# Out:
# ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %%
df["police_report_available"]=df["police_report_available"].str.replace("?","Unknown")

# %%
df["police_report_available"].value_counts()
# Out:
# NO         343
# Unknown    343
# YES        314
# Name: police_report_available, dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** Generally any missing, or NA value is replaced with the mean/median/mode as needed. however in each of the column data we see that the missing is almost equivalent to the data of the other 2 variables. So replacing them with any of them would skew the data. So lets make a category as "Unknown", this way our data is not skewed and the orignal data is retained. This would give us a better model   </span>

# %% [markdown]
# ## Object to DateTime

# %%
df['incident_date'] = pd.to_datetime(df['incident_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_state                 1000 non-null   object
#  3   policy_csl                   1000 non-null   object
#  4   policy_deductable            1000 non-null   int64
#  5   umbrella_limit               1000 non-null   int64
#  6   insured_sex                  1000 non-null   object
#  7   insured_education_level      1000 non-null   object
#  8   insured_occupation           1000 non-null   object
#  9   insured_hobbies              1000 non-null   object
#  10  insured_relationship         1000 non-null   object
#  11  capital-gains                1000 non-null   int64
#  12  capital-loss                 1000 non-null   int64
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** incident date is changed to date time column, so we can use it in our EDA now   </span>

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(df["fraud_reported"])

# %% [markdown]
# <span style='background:yellow'>**Observation:** we alreday saw aroud 25% of the Insurance Claims have fraud data, so lets analyse more and see which category has more fraud data   </span>

# %% [markdown]
# ## Bi-Variate Analysis

# %%
features=df.drop(columns='fraud_reported')

# %%
for col in df:
    fig,ax = plt.subplots(figsize=(25,6))
    
    sns.countplot(col,hue=df['fraud_reported'],palette=['red','green'],data=df)
    plt.ylabel('Count')
    plt.xlabel('' + ' ' + col.title())
    plt.title('- ' + ' ' + col.title())
    plt.legend(title=None,labels=["Yes",'No'])

# %% [markdown]
# <span style='background:yellow'>**Observation:** Months as customer, we see only spikes of red bar. That is towards the middle, so looks like they first understand the system and then start on the fraudulent activity.    </span>
#
#
#
# <span style='background:yellow'>**Observation:** Mid age people between 25- 50 years were more involved in the Fraudulent activity than the senior citizens   </span>
#
#
#
# <span style='background:yellow'>**Observation:** Policy state, policy csl, policy deductable, Gender, Education Level, insured relationship, all these places the data was almost similar for all categories. The red and green bards were of the similar shape  </span>
#
#
# <span style='background:yellow'>**Observation:** Hobbies and Occupation gets very interesting. It is the Senior Executive, who have the highest fraudulent data. And it’s the skilled people like the Chess Players, who are good at strategies. Next is the cross fit, who are fit and have an attractive frame are the highest fraudulent    </span>
#
# <span style='background:yellow'>**Observation:** Single Vehicle Collision is higher among Collision types. And rear collision is higher   </span>
#
# <span style='background:yellow'>**Observation:**  Major Damage has the highest Fraud. The red bar is higher than the green bar. So looks like they plan and do big ones.   </span>
#
# <span style='background:yellow'>**Observation:**   Authorities contacted, Incident City,  doesn’t have any impact</span>
#
# <span style='background:yellow'>**Observation:** South Carolina And New York states have higher Fraudulent data . Incident hour of 9 am has the lowest fraudulent data  </span>

# %% [markdown]
# <span style='background:yellow'>**Observation:** Single vehicle or three vehicle accidents seem to have high fraudulent cases.   </span>
#
# <span style='background:yellow'>**Observation:**  Fraudulent cases seem to be equal irrespective of the bodily injuries count </span>
#
#
# <span style='background:yellow'>**Observation:**  While 0, 1 and 3 witness cases have almost equal fraudulent counts, the ones with 2 witnesses seem to have a slightly higher fraud cases </span>
#
#
# <span style='background:yellow'>**Observation:**  Police report doesn’t seem to have an impact on whether the claim is fraudulent or not </span>
#
# <span style='background:yellow'>**Observation:** High value cars of bigger brands like Benz and BMW and Auto make like RAM or A5 seem to have higher fraud cases.   </span>
#
# <span style='background:yellow'>**Observation:**   Newer vehicles seem to have higher fraudulent cases compared to older vehicles</span>

# %%
df.shape
# Out:
# (1000, 33)

# %%
df.drop(columns=["incident_date"],inplace=True)

# %% [markdown]
# <span style='background:yellow'>**Observation:** From our EDA, we see that incident_date doesnt add value to our data, so lets drop it. Other columns are critical and we will retain them   </span>

# %% [markdown]
# # Label Encoding Target Variable

# %%
df["fraud_reported"].value_counts().sort_index()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
le = LabelEncoder()
df["fraud_reported"] = le.fit_transform(df["fraud_reported"])

# %%
df["fraud_reported"].value_counts().sort_index()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have used Label Encoding for our Target Variable. We can see that the N/Y has changed to 0/1 after Label Encoding   </span>

# %% [markdown]
# ## Ordinal Encoding

# %%
df.nunique()
# Out:
# months_as_customer             391
# age                             46
# policy_state                     3
# policy_csl                       3
# policy_deductable                3
# umbrella_limit                  11
# insured_sex                      2
# insured_education_level          7
# insured_occupation              14
# insured_hobbies                 20
# insured_relationship             6
# capital-gains                  338
# capital-loss                   354
# incident_type                    4
# collision_type                   4
# incident_severity                4
# authorities_contacted            5
# incident_state                   7
# incident_city                    7
# incident_hour_of_the_day        24
# number_of_vehicles_involved      4
# property_damage                  3
# bodily_injuries                  3
# witnesses                        4
# police_report_available          3
# injury_claim                   638
# property_claim                 626
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have multiple categorical columns. And multiple columns have only few values, so we can use Ordinal Encoding for our data  </span>

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Correlation matrix/heatmap

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(25, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# <span style='background:yellow'>**Observation:** Even when we have only half the matrix, data is not much readable. As the number of columns are huge. Lets foucs on our target variable and its relationship with all other variables   </span>

# %% [markdown]
# ## Correlation with target variable-Numerical + Plot

# %%
corr_matrix = df.corr()
corr_matrix["fraud_reported"].sort_values(ascending=True)
# Out:
# incident_severity             -0.41
# collision_type                -0.14
# incident_state                -0.05
# incident_type                 -0.05
# insured_hobbies               -0.05
# authorities_contacted         -0.05
# incident_city                 -0.04
# policy_csl                    -0.04
# auto_make                     -0.03
# police_report_available       -0.02
# capital-gains                 -0.02
# capital-loss                  -0.01
# auto_model                     0.00
# insured_occupation             0.00
# incident_hour_of_the_day       0.00
# auto_year                      0.01
# insured_education_level        0.01
# age                            0.01
# policy_deductable              0.01
# months_as_customer             0.02
# insured_relationship           0.02
# policy_state                   0.03
# insured_sex                    0.03
# bodily_injuries                0.03
# witnesses                      0.05
# number_of_vehicles_involved    0.05
# ...

# %%
plt.figure(figsize=(22,7))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind="bar",color='c')
plt.xlabel("fraud_reported",fontsize=14)
plt.ylabel("Column with target names",fontsize=14)
plt.title("Correlation with target",fontsize=14)
plt.show()

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have a good spread of data. Columns above the axis and positively co-related. Columns below the axis are negatively co-related. Columns near the axis have close to "0" co-relation  </span>

# %% [markdown]
# # Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

df_out=df[(z<3).all(axis=1)]

# %%
df_out.shape
# Out:
# (983, 32)

# %%
df.shape
# Out:
# (1000, 32)

# %%
((1000-983)/1000)*100
# Out:
# 1.7000000000000002

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have only 1.7% of data as outliers. Which is very less and we can drop them !   </span>

# %% [markdown]
# # Skewness

# %%
df_out.skew()
# Out:
# months_as_customer             0.37
# age                            0.48
# policy_state                  -0.03
# policy_csl                     0.10
# policy_deductable              0.48
# umbrella_limit                 1.81
# insured_sex                    0.14
# insured_education_level        0.00
# insured_occupation            -0.05
# insured_hobbies               -0.06
# insured_relationship           0.08
# capital-gains                  0.47
# capital-loss                  -0.37
# incident_type                  0.09
# collision_type                 0.13
# incident_severity              0.28
# authorities_contacted         -0.11
# incident_state                -0.15
# incident_city                  0.05
# incident_hour_of_the_day      -0.03
# number_of_vehicles_involved    0.51
# property_damage                0.06
# bodily_injuries                0.01
# witnesses                      0.02
# police_report_available        0.06
# injury_claim                   0.27
# ...

# %%
df_skew=df_out.drop("fraud_reported",axis=1)
#we have created a new dataframe called df_skew to handle skewness and dropped the target variable "fraud_reported"

# %%
df_skew.skew()
#checking the skewness
# Out:
# months_as_customer             0.37
# age                            0.48
# policy_state                  -0.03
# policy_csl                     0.10
# policy_deductable              0.48
# umbrella_limit                 1.81
# insured_sex                    0.14
# insured_education_level        0.00
# insured_occupation            -0.05
# insured_hobbies               -0.06
# insured_relationship           0.08
# capital-gains                  0.47
# capital-loss                  -0.37
# incident_type                  0.09
# collision_type                 0.13
# incident_severity              0.28
# authorities_contacted         -0.11
# incident_state                -0.15
# incident_city                  0.05
# incident_hour_of_the_day      -0.03
# number_of_vehicles_involved    0.51
# property_damage                0.06
# bodily_injuries                0.01
# witnesses                      0.02
# police_report_available        0.06
# injury_claim                   0.27
# ...

# %%
print("Number of numerical columns: ",len(df_skew.skew()))
print("Number of columns which are skewed not in -0.5 to +0.5 range: ",len(df_skew.skew().loc[abs(df_skew.skew())>0.5]))
# Out:
# Number of numerical columns:  31
# Number of columns which are skewed not in -0.5 to +0.5 range:  3

# %%
skew_col= (df_skew.skew().loc[abs(df_skew.skew())>0.5])
skew_col.head()
# Out:
# umbrella_limit                 1.81
# number_of_vehicles_involved    0.51
# vehicle_claim                 -0.62
# dtype: float64

# %% [markdown]
# <span style='background:yellow'>**Observation:** Only 3 columns are skewed. Umbrella limit we saw in the EDA, it is skewed. So we will leave it as it is. Number of vehicles limited is just too close to the skew range so we will leave it as it is. Vehicle claim, is part of the Total claim, and vehicle accidents are generally high as well, so we need not handle the skewness for that as well. We are good to go to Model building  </span>

# %% [markdown]
# # Model Building (Classification)

# %% [markdown]
# # Importing Libraries for Model Building (Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Train & Test Data

# %%
df_x=df_skew
df_x.head()
# Out:
#    months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                 328   48          2.00        1.00               1000
# 1                 228   42          1.00        1.00               2000
# 2                 134   29          2.00        0.00               2000
# 3                 256   41          0.00        1.00               2000
# 4                 228   44          0.00        2.00               1000
#
#    umbrella_limit  insured_sex  insured_education_level  insured_occupation  \
# 0               0         1.00                     4.00                2.00
# 1         5000000         1.00                     4.00                6.00
# 2         5000000         0.00                     6.00               11.00
# 3         6000000         0.00                     6.00                1.00
# 4         6000000         1.00                     0.00               11.00
#
#    insured_hobbies  insured_relationship  capital-gains  capital-loss  \
# ...

# %%
y=df_out["fraud_reported"]
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: fraud_reported, dtype: int32

# %% [markdown]
# # Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.head()
# Out:
#    months_as_customer   age  policy_state  policy_csl  policy_deductable  \
# 0                1.07  0.99          1.18        0.07              -0.22
# 1                0.21  0.33         -0.02        0.07               1.41
# 2               -0.61 -1.08          1.18       -1.18               1.41
# 3                0.45  0.22         -1.23        0.07               1.41
# 4                0.21  0.55         -1.23        1.31              -0.22
#
#    umbrella_limit  insured_sex  insured_education_level  insured_occupation  \
# 0           -0.47         1.07                     0.53               -1.15
# 1            1.89         1.07                     0.53               -0.16
# 2            1.89        -0.93                     1.56                1.09
# 3            2.37        -0.93                     1.56               -1.40
# 4            2.37         1.07                    -1.52                1.09
#
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We saw the data was not standard scale, as umbrella limit was very high. If we dont scale the data, the model will be affected. So we have done standard scaling and see the data looks fine now for modle building   </span>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=43)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (786, 31)
# (197, 31)
# (786,)
# (197,)

# %%
y_test.head()
# Out:
# 723    0
# 543    0
# 904    0
# 633    1
# 291    0
# Name: fraud_reported, dtype: int32

# %% [markdown]
# ## Over Sampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
random_over_sampler = RandomOverSampler()

# %%
x_res,y_res=random_over_sampler.fit_resample(x,y)

# %% [markdown]
# <span style='background:yellow'>**Observation:** We already saw our data is Imbalanced. So we have to balance the data using Over Sampling   </span>

# %% [markdown]
# ## Best Random State

# %%
maxAccu=0
BestRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)    
    mod=DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    f1=f1_score(y_test,pred,average="macro")
    if f1>maxAccu:
        maxAccu=f1
        BestRs=i
print("Best accuracy is ", maxAccu,"on Random_state  ",BestRs)
# Out:
# Best accuracy is  0.7959077959077958 on Random_state   104

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have got our Best Random State, lets use this in our model building  </span>

# %% [markdown]
# ## Instantiating the Models

# %%
lg=LogisticRegression()
gnb=GaussianNB()
sv=SVC()
rf=RandomForestClassifier(n_estimators=100)
ad=AdaBoostClassifier(n_estimators=100)
dtc=DecisionTreeClassifier()

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have instantiated 6 algos and we will use them in our Model Building   </span>

# %% [markdown]
# ## Model Building and checking Evaluation Scores

# %%
model=[lg,gnb,rf,ad,dtc,sv]

for m in model:
    m.fit(x_res,y_res)
    pred=m.predict(x_res)
    print("\n f1 score: of ",m)
    print(f1_score(y_res,pred))
    print("\n  Classificatin report:  of ",m)
    print(classification_report(y_res,pred))
    print("***************************************")
    score=cross_val_score(m,x_res,y_res,scoring="f1",cv=5)
    print(score)
    print("mean of cross val with scoring= accuarcy:",score.mean())
    print("***************************************")
# Out:
#  f1 score: of  LogisticRegression()
# 0.7572944297082229
#
#   Classificatin report:  of  LogisticRegression()
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75       742
#            1       0.75      0.77      0.76       742
#
#     accuracy                           0.75      1484
#    macro avg       0.75      0.75      0.75      1484
# weighted avg       0.75      0.75      0.75      1484
#
# ***************************************
# [0.7440273  0.73311897 0.75241158 0.72108844 0.76315789]
# mean of cross val with scoring= accuarcy: 0.7427608360978104
# ***************************************
#
#  f1 score: of  GaussianNB()
# 0.7181044957472661
#
#   Classificatin report:  of  GaussianNB()
#               precision    recall  f1-score   support
#
#            0       0.74      0.58      0.65       742
#            1       0.65      0.80      0.72       742
#
#     accuracy                           0.69      1484
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have 6 models, and we have done the F1 score, Classification report and the Cross validation. This was run especially to see the F1 score of 0 & 1 class. It is almost equal in all models. So this shows that are data is balanced. Decision tree & Random Forest tops our chart. Lets closely look at at F1 score and Cross validation in the next step   </span>

# %% [markdown]
# # Model Building and checking the Evaluation Scores

# %%
modelList=[("Log Reg",lg),("Ada boost",ad),("Dec Tree Classifier", dtc),("Random Forest Class",rf),("Naive Bayes-G", gnb),("Support Vector",sv)]

def GetAccuracy(x,y,modelList):
    x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=.20,random_state=BestRs)
    ModelName= []
    modelf1=[]
    modelCrossval=[]
    f1CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(x_train,y_train)
        pred=modelInstance.predict(x_test)
        f1score= f1_score(y_test,pred,average="macro")
        modelf1.append(f1score)
        crossval=cross_val_score(modelInstance,x_res,y_res,scoring="f1",cv=5).mean()
        modelCrossval.append(crossval)
        f1CVDiff.append(f1score-crossval)
    df_acc=pd.DataFrame({"Name":ModelName,
                         "f1": modelf1,
                         "CrossValidation":modelCrossval,
                          "Difference in Accuracy": f1CVDiff})
    return df_acc
GetAccuracy(x_res,y_res,modelList)
# Out:
#                   Name   f1  CrossValidation  Difference in Accuracy
# 0              Log Reg 0.73             0.74                   -0.02
# 1            Ada boost 0.86             0.86                    0.00
# 2  Dec Tree Classifier 0.90             0.90                   -0.00
# 3  Random Forest Class 0.92             0.93                   -0.01
# 4        Naive Bayes-G 0.71             0.72                   -0.01
# 5       Support Vector 0.84             0.85                   -0.01

# %% [markdown]
# <span style='background:yellow'>**Observation:** Least diff betwee F1 and Cross validation is 0.01. And when we check which has high F1 and CV scores, we see  Random Forest and Decision Tree  tops our chart. So lets analyse the models further using AUC ROC Curve and hyper parameter tuning.   </span>

# %% [markdown]
# # AUC ROC

# %%
from sklearn.metrics import plot_roc_curve

model=[lg,gnb,rf,ad,dtc,sv]
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=.20,random_state=BestRs)



for m in model:
    plot_roc_curve(m,x_test,y_test)
    plt.title("AUC ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.show()

# %% [markdown]
# <span style='background:yellow'>**Observation:** Clear winner in the AUC ROC is Random Forest. Since it is the highest we have seen in F1, Classification Report, Cross validation and AUC ROC, lets use in hyper parameter tuning and see if we can improve it  </span>

# %% [markdown]
# # HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters ={
              "bootstrap": [True,False],
              "criterion" : ["gini", "entropy"],              
             }

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_res,y_res)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy']})

# %%
GCV.best_params_
# Out:
# {'bootstrap': False, 'criterion': 'gini'}

# %%
mod=RandomForestClassifier(bootstrap= False, criterion='gini')
mod.fit(x_res,y_res)
pred=mod.predict(x_res)
print(f1_score(y_res,pred,average="macro"))
# Out:
# 1.0

# %% [markdown]
# <span style='background:yellow'>**Observation:** Our score has improved from 92% to a perfect 100% score. So we not do hyper tuning of other models, as Random Forest has already been giving us good results in all evaluation models. Lests save this model and share to Biz   </span>

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(mod,"InsuranceFraud.pkl")
# Out:
# ['InsuranceFraud.pkl']

# %% [markdown]
# # Loading the Model

# %%
model=joblib.load("InsuranceFraud.pkl")

# %%
prediction=model.predict(x_res)

# %%
print(f1_score(y_res,pred,average="macro"))
# Out:
# 1.0

# %%
prediction=pd.DataFrame(prediction) #converting to a Data Frame

# %%
prediction.head()  #checking the top 5 values, to double check fi there are predictions
# Out:
#    0
# 0  1
# 1  1
# 2  0
# 3  1
# 4  0

# %% [markdown]
# # Summary

# %% [markdown]
# **Insurance Fraud Detection**
#
# **Data Loading**
#
# Data loaded properly and we see there are few “?” and na values which needs to be handled.
#
# **Pre Processing**
#
# There were totally 1000 rows of data. So any column which had more than 900 unique values were dropped, as they don’t add value. Also column with no values were dropped. The “?” were replaced as Unknown category
#
# **EDA**
#
# EDA gave us some interesting info on who were the fraud claims more and compared within the profession, city, state, age, profession, type of claims etc. Interesting we see that people with hobbies as Chess and Cross Fittness had the highest fraud claim. Also people with High claims had more fraudulent data
#
# **Skewness & Outliers**
# Outliers was less than 2% of data, so we removed them. Skewness was present only in 3 columns and they didn’t had to be handled.
#
# **Ordinal Encoding**
#
# Since there were lot of Ordinal Data present, we used the Ordinal encoding. And then we did re-shape.
#
# **Standard Scalar**
# Used Standard Scalar as the range was high and we had to bring everything to one scale
#
#
#
# **Model Building**
# Was done in 2 ways after finding the Best Random state
# 1.	Model 1: We have used 6 models and 3 Evaluation Techniques (F1 Score, Classification Report & Cross Validation). In the Classification Report we saw the score equal in both classes, which says it is a good model. Decision Tree & Random forest topped the charts
# 2.	Model2: We have used 6 models and 3 Evaluation Techniques (F1 Score, Cross Validation, diff between F1 Score & Cross Validation). Almost every model the diff was lowest and the top ones were chosen- which again was Decision Tree & Random forest
# 3.	Model 3: ROC_AUC for model evaluation of 6 models. Random forest topped the charts
#
# **Hyper Parameter Tuning**
# 1.	Hyper Tuning was done on Random forest) and had the perfect score 100%. It was used to Save & Load the Model
# **Saving & Loading**
# 1.	Random forest model was saved. Later it was loaded and test for a sanity check. The scores matched
# 2.	We are good to share this saved model to Biz
