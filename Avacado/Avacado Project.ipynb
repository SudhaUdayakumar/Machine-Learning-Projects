# %% [markdown]
# ![avacado2.gif](attachment:avacado2.gif)
# ![Avacado%203.gif](attachment:Avacado%203.gif)

# %% [markdown]
# ![name.gif](attachment:name.gif)

# %% [markdown]
# # Avacado Price Analysis- Python Machine Learning

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Avacado-Price-Analysis--Python-Machine-Learning" data-toc-modified-id="Avacado-Price-Analysis--Python-Machine-Learning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Avacado Price Analysis- Python Machine Learning</a></span></li><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Choosing-the-Right-Tools" data-toc-modified-id="Choosing-the-Right-Tools-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Choosing the Right Tools</a></span><ul class="toc-item"><li><span><a href="#Importing-and-Installing-the-Right-Packages" data-toc-modified-id="Importing-and-Installing-the-Right-Packages-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Importing and Installing the Right Packages</a></span></li><li><span><a href="#Handling-Warnings" data-toc-modified-id="Handling-Warnings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Handling Warnings</a></span></li></ul></li><li><span><a href="#Loading-the-Dataset" data-toc-modified-id="Loading-the-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Loading the Dataset</a></span></li><li><span><a href="#Initial-Analysis-of-Data" data-toc-modified-id="Initial-Analysis-of-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Initial Analysis of Data</a></span></li><li><span><a href="#Pre-Processing-of-Data" data-toc-modified-id="Pre-Processing-of-Data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Pre-Processing of Data</a></span><ul class="toc-item"><li><span><a href="#Handling-Duplciate-Rows" data-toc-modified-id="Handling-Duplciate-Rows-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Handling Duplciate Rows</a></span></li><li><span><a href="#Handling-Null-Values" data-toc-modified-id="Handling-Null-Values-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Handling Null Values</a></span></li><li><span><a href="#Dropping-Columns" data-toc-modified-id="Dropping-Columns-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Dropping Columns</a></span></li><li><span><a href="#Convert-Date-column-from-Object-to-Datetime-Type" data-toc-modified-id="Convert-Date-column-from-Object-to-Datetime-Type-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Convert Date column from Object to Datetime Type</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Univaraiate-Analysis" data-toc-modified-id="Univaraiate-Analysis-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Univaraiate Analysis</a></span><ul class="toc-item"><li><span><a href="#Target-Variable" data-toc-modified-id="Target-Variable-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Target Variable</a></span></li><li><span><a href="#All-columns-Histogram" data-toc-modified-id="All-columns-Histogram-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>All columns Histogram</a></span></li></ul></li><li><span><a href="#Bi-Variate-Analysis" data-toc-modified-id="Bi-Variate-Analysis-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Bi Variate Analysis</a></span></li><li><span><a href="#Bi-Variate-Analysis-Timeline-Vs-Target-Variable" data-toc-modified-id="Bi-Variate-Analysis-Timeline-Vs-Target-Variable-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Bi Variate Analysis Timeline Vs Target Variable</a></span><ul class="toc-item"><li><span><a href="#Year-vs-Target" data-toc-modified-id="Year-vs-Target-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Year vs Target</a></span></li><li><span><a href="#Creating-a-month-column,-to-see-which-month-has-more-sales" data-toc-modified-id="Creating-a-month-column,-to-see-which-month-has-more-sales-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Creating a month column, to see which month has more sales</a></span></li><li><span><a href="#Timeline-vs-Avg-Price" data-toc-modified-id="Timeline-vs-Avg-Price-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Timeline vs Avg Price</a></span></li></ul></li><li><span><a href="#Regions" data-toc-modified-id="Regions-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Regions</a></span></li><li><span><a href="#Multi-Variate-Analysis" data-toc-modified-id="Multi-Variate-Analysis-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Multi Variate Analysis</a></span></li></ul></li><li><span><a href="#Post-Processing-Data-after-EDA" data-toc-modified-id="Post-Processing-Data-after-EDA-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Post Processing Data after EDA</a></span><ul class="toc-item"><li><span><a href="#Dropping-Date-&amp;-Month-Column" data-toc-modified-id="Dropping-Date-&amp;-Month-Column-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Dropping Date &amp; Month Column</a></span></li></ul></li><li><span><a href="#Label-Encoding" data-toc-modified-id="Label-Encoding-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Label Encoding</a></span></li><li><span><a href="#Outlier" data-toc-modified-id="Outlier-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Outlier</a></span></li><li><span><a href="#Skewness" data-toc-modified-id="Skewness-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Skewness</a></span></li><li><span><a href="#Standard-Scalar" data-toc-modified-id="Standard-Scalar-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Standard Scalar</a></span></li><li><span><a href="#Importing-Libraries-for-Model-Building" data-toc-modified-id="Importing-Libraries-for-Model-Building-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Importing Libraries for Model Building</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Finding-best-Random-state" data-toc-modified-id="Finding-best-Random-state-13.0.1"><span class="toc-item-num">13.0.1&nbsp;&nbsp;</span>Finding best Random state</a></span></li></ul></li><li><span><a href="#Building-Model-with-RMSE" data-toc-modified-id="Building-Model-with-RMSE-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Building Model with RMSE</a></span></li><li><span><a href="#Building-Model-with-R2" data-toc-modified-id="Building-Model-with-R2-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>Building Model with R2</a></span></li></ul></li><li><span><a href="#Hyper-Parameter-Tuning" data-toc-modified-id="Hyper-Parameter-Tuning-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Hyper Parameter Tuning</a></span></li><li><span><a href="#Ensemble-Technique" data-toc-modified-id="Ensemble-Technique-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Ensemble Technique</a></span></li><li><span><a href="#MOdel-building-by-removing-more-columns" data-toc-modified-id="MOdel-building-by-removing-more-columns-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>MOdel building by removing more columns</a></span><ul class="toc-item"><li><span><a href="#Building-Model-with-RMSE-(Feature-Engineering)" data-toc-modified-id="Building-Model-with-RMSE-(Feature-Engineering)-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>Building Model with RMSE (Feature Engineering)</a></span></li><li><span><a href="#Building-Model-with-RMSE-(Feature-Engineering)" data-toc-modified-id="Building-Model-with-RMSE-(Feature-Engineering)-16.2"><span class="toc-item-num">16.2&nbsp;&nbsp;</span>Building Model with RMSE (Feature Engineering)</a></span></li></ul></li><li><span><a href="#PCA" data-toc-modified-id="PCA-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>PCA</a></span><ul class="toc-item"><li><span><a href="#PCA-Model-Building-with-R2" data-toc-modified-id="PCA-Model-Building-with-R2-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>PCA Model Building with R2</a></span></li><li><span><a href="#PCA-Model-with-RMSE" data-toc-modified-id="PCA-Model-with-RMSE-17.2"><span class="toc-item-num">17.2&nbsp;&nbsp;</span>PCA Model with RMSE</a></span></li></ul></li><li><span><a href="#Saving-the-Model" data-toc-modified-id="Saving-the-Model-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Saving the Model</a></span></li><li><span><a href="#Loading-the-Model" data-toc-modified-id="Loading-the-Model-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Loading the Model</a></span></li></ul></div>

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Avacado Project
# Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
#
#
# Inspiration /Label
#
# Your task is to make a mode that can consider the data provided and predict the Average Price.

# %% [markdown]
# # Choosing the Right Tools

# %% [markdown]
# ## Importing and Installing the Right Packages

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)       # To display all the data in each column
pd.set_option('display.precision', 5)               # To display values only upto three decimal places.
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()
pd.options.display.float_format = '{:.2f}'.format  
import numpy as np
import seaborn as sns
sns.set(style='whitegrid', font_scale = 1.3, color_codes=True)
from sklearn.preprocessing import LabelEncoder


import matplotlib.pyplot as plt
# %matplotlib inline


import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

from datetime import datetime, timedelta #for datetime, as we have a date column in this dataset

# %% [markdown]
# ## Handling Warnings

# %%
warnings.filterwarnings('ignore') # ignore warnings.
# %config IPCompleter.greedy = True # autocomplete feature.
pd.options.display.max_rows = None # set maximum rows that can be displayed in notebook.
pd.options.display.max_columns = None # set maximum columns that can be displayed in notebook.
pd.options.display.precision = 4 # set the precision of floating point numbers.

# %% [markdown]
# # Loading the Dataset

# %%
 # Importing training dataset using pd.read_csv from github. Not saving the file locally 
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv")

# %%
#save the CSV file to a local folder, so that we can use it while uploading to Github & Then commenting it out 
#df.to_csv("Avacado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume    4046      4225  \
# 0        0.00  27-12-2015          1.33      64236.62 1036.74  54454.85
# 1        1.00  20-12-2015          1.35      54876.98  674.28  44638.81
# 2        2.00  13-12-2015          0.93     118220.22  794.70 109149.67
# 3        3.00  06-12-2015          1.08      78992.15 1132.00  71976.41
# 4        4.00  29-11-2015          1.28      51039.60  941.48  43838.39
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0  48.16     8696.87     8603.62       93.25         0.00  conventional
# 1  58.33     9505.56     9408.07       97.49         0.00  conventional
# 2 130.50     8145.35     8042.21      103.14         0.00  conventional
# 3  72.58     5811.16     5677.40      133.76         0.00  conventional
# 4  75.78     6183.95     5986.26      197.69         0.00  conventional
#
#      year  region
# 0 2015.00  Albany
# 1 2015.00  Albany
# 2 2015.00  Albany
# 3 2015.00  Albany
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:** The dataset is loading properly. Lets go to the initial analysis   </span>

# %% [markdown]
# # Initial Analysis of Data

# %%
df.shape
# Out:
# (16468, 14)

# %% [markdown]
# <span style='background:yellow'>**Observation:** There are 16468 rows and 14 columns   </span>

# %%
df.nunique()
# Out:
# Unnamed: 0        52
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# type               1
# year               2
# region            51
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** The Average price which is our target variable has 113 values, so might be a regression model. Or we have to check if it can binned to make it a classification model. Type there is only 1 , so we can drop it. Unnamed 0 ned to check what column it is    </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# <span style='background:yellow'>**Observation:** There are clearly lot of missing values and 3 object columns. Need to check if we need to change the Date column from Object type as well    </span>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** There are lot of null values, we need to remove them before doing EDA itself   </span>

# %% [markdown]
# # Pre-Processing of Data

# %% [markdown]
# ## Handling Duplciate Rows

# %%
df[df.duplicated(keep='first')].shape
# Out:
# (14950, 14)

# %%
duplicates = df[df.duplicated()]
print('There are {} duplicates out of total {} rows'.format(duplicates.shape[0], df.shape[0]))
# Out:
# There are 14950 duplicates out of total 16468 rows

# %% [markdown]
# <span style='background:yellow'>**Observation:** 14950 duplicate rows (92% of data) has duplicates. So we need to remove them   </span>

# %%
df.drop_duplicates( keep='first', inplace=True)

# %%
df.shape
# Out:
# (1518, 14)

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have  retained the first row and remove the remaining duplicate rows. Also on checking the df.shape, we can see the rows have been removed    </span>

# %%
duplicates = df[df.duplicated()]
print('There are {} duplicates out of total {} rows'.format(duplicates.shape[0], df.shape[0]))
# Out:
# There are 0 duplicates out of total 1518 rows

# %% [markdown]
# <span style='background:yellow'>**Observation:** Again checked if there are any duplicate rows and we see there are 0 duplicate rows now.   </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1518 entries, 0 to 1517
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 177.9+ KB

# %% [markdown]
# <span style='background:yellow'>**Observation:** Date is an object column, we might need to convert it to Time Series before using it. Type & Region are the only other Object columns. Also we see there are no missing values now   </span>

# %%
df.nunique()
# Out:
# Unnamed: 0        52
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# type               1
# year               2
# region            51
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** Type is only one, we can remove if needed.     </span>

# %% [markdown]
# ## Handling Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      1
# Date            1
# AveragePrice    1
# Total Volume    1
# 4046            1
# 4225            1
# 4770            1
# Total Bags      1
# Small Bags      1
# Large Bags      1
# XLarge Bags     1
# type            1
# year            1
# region          1
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** every column is having a missing value, lets see if all are in the same row or in different rows. if they are in different rows, we might need to replace them with mean/median/mode as needed. Else if it is only 1 row, we can remove the entire row    </span>

# %%
df1 = df[df.isna().any(axis=1)]
df1
# Out:
#       Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 1517         nan  NaN           nan           nan   nan   nan   nan
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 1517         nan         nan         nan          nan  NaN   nan    NaN

# %% [markdown]
# <span style='background:yellow'>**Observation:** There is only 1 row, with "nan" values, so lets remove this row   </span>

# %%
df.drop(1517,inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have removed the row "1517" which had the "nan" values. we checked again for null values and there are none now  </span>

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume    4046      4225  \
# 0        0.00  27-12-2015          1.33      64236.62 1036.74  54454.85
# 1        1.00  20-12-2015          1.35      54876.98  674.28  44638.81
# 2        2.00  13-12-2015          0.93     118220.22  794.70 109149.67
# 3        3.00  06-12-2015          1.08      78992.15 1132.00  71976.41
# 4        4.00  29-11-2015          1.28      51039.60  941.48  43838.39
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0  48.16     8696.87     8603.62       93.25         0.00  conventional
# 1  58.33     9505.56     9408.07       97.49         0.00  conventional
# 2 130.50     8145.35     8042.21      103.14         0.00  conventional
# 3  72.58     5811.16     5677.40      133.76         0.00  conventional
# 4  75.78     6183.95     5986.26      197.69         0.00  conventional
#
#      year  region
# 0 2015.00  Albany
# 1 2015.00  Albany
# 2 2015.00  Albany
# 3 2015.00  Albany
# ...

# %% [markdown]
# ## Dropping Columns

# %%
df.drop(["type"],axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume    4046      4225  \
# 0        0.00  27-12-2015          1.33      64236.62 1036.74  54454.85
# 1        1.00  20-12-2015          1.35      54876.98  674.28  44638.81
# 2        2.00  13-12-2015          0.93     118220.22  794.70 109149.67
# 3        3.00  06-12-2015          1.08      78992.15 1132.00  71976.41
# 4        4.00  29-11-2015          1.28      51039.60  941.48  43838.39
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags    year  region
# 0  48.16     8696.87     8603.62       93.25         0.00 2015.00  Albany
# 1  58.33     9505.56     9408.07       97.49         0.00 2015.00  Albany
# 2 130.50     8145.35     8042.21      103.14         0.00 2015.00  Albany
# 3  72.58     5811.16     5677.40      133.76         0.00 2015.00  Albany
# 4  75.78     6183.95     5986.26      197.69         0.00 2015.00  Albany

# %% [markdown]
# <span style='background:yellow'>**Observation:** We saw that column "Type" has only 1 data, so we dropped the column and also checked that is not in the dataframe. The permanent deletion of the column was done by using inplace=True   </span>

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 1512       10.00  16-10-2016          1.39     190846.01 57529.11 56366.66
# 1513       11.00  09-10-2016          1.51     178235.75 43325.87 52189.61
# 1514       12.00  02-10-2016          1.48     178410.82 46364.75 52893.38
# 1515       13.00  25-09-2016          1.47     189131.52 54110.79 53593.58
# 1516       14.00  18-09-2016          1.43     182978.30 43116.41 54193.42
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags    year  \
# 1512 17531.78    59418.46    48823.53    10354.65       240.28 2016.00
# 1513 19419.57    63300.70    54704.14     8596.56         0.00 2016.00
# 1514 16736.92    62415.77    53332.61     8258.16       825.00 2016.00
# 1515 17495.42    63931.73    55653.47     8278.26         0.00 2016.00
# 1516 16563.91    69104.56    57456.21    11648.35         0.00 2016.00
#
#          region
# 1512  Charlotte
# 1513  Charlotte
# 1514  Charlotte
# 1515  Charlotte
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year',
#        'region'],
#       dtype='object')

# %%
df['Unnamed: 0'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.00
# 1       1.00
# 2       2.00
# 3       3.00
# 4       4.00
# 5       5.00
# 6       6.00
# 7       7.00
# 8       8.00
# 9       9.00
# 10     10.00
# 11     11.00
# 12     12.00
# 13     13.00
# 14     14.00
# 15     15.00
# 16     16.00
# 17     17.00
# 18     18.00
# 19     19.00
# 20     20.00
# 21     21.00
# 22     22.00
# 23     23.00
# 24     24.00
# 25     25.00
# 26     26.00
# 27     27.00
# 28     28.00
# 29     29.00
# 30     30.00
# 31     31.00
# 32     32.00
# 33     33.00
# 34     34.00
# 35     35.00
# 36     36.00
# 37     37.00
# 38     38.00
# 39     39.00
# 40     40.00
# 41     41.00
# 42     42.00
# 43     43.00
# 44     44.00
# 45     45.00
# 46     46.00
# 47     47.00
# 48     48.00
# 49     49.00
# 50     50.00
# 51     51.00
# 52      0.00
# 53      1.00
# 54      2.00
# 55      3.00
# 56      4.00
# 57      5.00
# 58      6.00
# 59      7.00
# 60      8.00
# 61      9.00
# 62     10.00
# ...

# %% [markdown]
# <span style='background:yellow'>**Observation:**  Looks like the serial number is repeating in batches of 51. So we can remove this column  </span>

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume    4046      4225   4770  \
# 0  27-12-2015          1.33      64236.62 1036.74  54454.85  48.16
# 1  20-12-2015          1.35      54876.98  674.28  44638.81  58.33
# 2  13-12-2015          0.93     118220.22  794.70 109149.67 130.50
# 3  06-12-2015          1.08      78992.15 1132.00  71976.41  72.58
# 4  29-11-2015          1.28      51039.60  941.48  43838.39  75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags    year  region
# 0     8696.87     8603.62       93.25         0.00 2015.00  Albany
# 1     9505.56     9408.07       97.49         0.00 2015.00  Albany
# 2     8145.35     8042.21      103.14         0.00 2015.00  Albany
# 3     5811.16     5677.40      133.76         0.00 2015.00  Albany
# 4     6183.95     5986.26      197.69         0.00 2015.00  Albany

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have removed all the columns that were not needed   </span>

# %% [markdown]
# ## Convert Date column from Object to Datetime Type

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  year          1517 non-null   float64
#  11  region        1517 non-null   object
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 154.1+ KB

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have converted Date column from Object to Datetime, to use in our data. Now we might get some intersting data   </span>

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univaraiate Analysis

# %% [markdown]
# ### Target Variable

# %%
df["AveragePrice"].value_counts(normalize=True,sort=True)*100
# Out:
# 1.08   3.03
# 0.99   2.90
# 1.03   2.90
# 1.09   2.83
# 1.10   2.83
# 1.11   2.70
# 1.05   2.64
# 1.04   2.57
# 0.98   2.44
# 1.19   2.44
# 1.07   2.37
# 1.15   2.24
# 1.17   2.18
# 1.12   2.11
# 1.01   2.04
# 0.97   1.98
# 1.18   1.98
# 1.13   1.91
# 1.06   1.91
# 1.16   1.91
# 1.02   1.91
# 1.00   1.85
# 1.23   1.71
# 1.22   1.71
# 1.24   1.65
# 1.21   1.58
# 0.93   1.58
# 0.96   1.58
# 1.25   1.52
# 1.14   1.45
# 1.26   1.32
# 1.20   1.32
# 0.95   1.32
# 0.94   1.12
# 0.89   1.12
# 0.90   1.05
# 0.83   0.99
# 1.33   0.99
# 1.27   0.99
# 0.79   0.92
# 1.28   0.92
# 1.36   0.86
# 0.92   0.86
# 1.32   0.79
# 1.30   0.73
# 0.91   0.73
# 0.82   0.73
# 0.80   0.73
# 0.74   0.73
# 1.34   0.73
# 1.40   0.66
# 0.77   0.66
# 1.29   0.59
# 0.88   0.59
# 1.37   0.59
# 0.75   0.59
# 0.85   0.59
# 0.81   0.53
# 0.76   0.53
# 0.70   0.53
# 0.78   0.53
# 1.39   0.46
# 1.35   0.46
# 0.67   0.46
# 0.71   0.46
# 0.72   0.46
# 0.87   0.40
# 1.31   0.40
# 1.43   0.40
# 1.38   0.33
# 1.45   0.33
# ...

# %%
plt.hist(df['AveragePrice'],facecolor='green',edgecolor='black',bins=10)
# Out:
# (array([ 20.,  47., 113., 169., 433., 393., 211.,  91.,  25.,  15.]),
#  array([0.49 , 0.609, 0.728, 0.847, 0.966, 1.085, 1.204, 1.323, 1.442,
#         1.561, 1.68 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# <span style='background:yellow'>**Observation:** Wanted to check if we can create buckets of the target column if they are not equally spread. Looks like it cannot be done, every value contributes 0.07% to 3.03% to the data. So we will leave it as it is and treat this as a regression Value    </span>

# %% [markdown]
# ### All columns Histogram

# %%
df.hist(figsize = (15,15),color='b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002111D4AB9D0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bi Variate Analysis

# %% [markdown]
# ## Bi Variate Analysis Timeline Vs Target Variable

# %% [markdown]
# ### Year vs Target

# %%
df.groupby("year")["AveragePrice"].count().plot.bar()

# %%
sns.countplot(df.groupby("year")["AveragePrice"].mean())

# %% [markdown]
# <span style='background:yellow'>**Observation:** There have been more sales in 2015 than in 2016. However the average is similar   </span>

# %% [markdown]
# ### Creating a month column, to see which month has more sales

# %%
df['Month']=df['Date'].apply(lambda x:x.month)

# %%
df['Month'].nunique()
# Out:
# 12

# %%
df['Month'].value_counts().sort_index().plot.bar()

# %% [markdown]
# <span style='background:yellow'>**Observation:** We can see the monthly sales differ. Holiday Season like Christmas (12-December) and New year (1)have higher values. March , May & August have higher sales as well   </span>

# %% [markdown]
# ### Timeline vs Avg Price

# %%
Timeline=df.groupby('Date').mean()
plt.figure(figsize=(18,8))
Timeline['AveragePrice'].plot()
plt.title('Timeline vs Average Price')
# Out:
# Text(0.5, 1.0, 'Timeline vs Average Price')

# %% [markdown]
# <span style='background:yellow'>**Observation:** We can see the price is lowest around 2015 and starts to catch up. Peaks around mid 2016, and keeps dropping and peaking again seasonally   </span>

# %% [markdown]
# ## Regions

# %%
df.groupby("region")["AveragePrice"].count().plot.bar(plt.figure(figsize=(18,8)))

# %% [markdown]
# <span style='background:yellow'>**Observation:** Alphabetically listed the region. california has the highest and Los Angeles the lowest   </span>

# %% [markdown]
# ## Multi Variate Analysis

# %%
dfcor=df.corr()
dfcor
# Out:
#               AveragePrice  Total Volume  4046  4225  4770  Total Bags  \
# AveragePrice          1.00         -0.14 -0.19 -0.09 -0.10       -0.11
# Total Volume         -0.14          1.00  0.99  0.99  0.93        0.97
# 4046                 -0.19          0.99  1.00  0.95  0.90        0.93
# 4225                 -0.09          0.99  0.95  1.00  0.93        0.95
# 4770                 -0.10          0.93  0.90  0.93  1.00        0.93
# Total Bags           -0.11          0.97  0.93  0.95  0.93        1.00
# Small Bags           -0.10          0.96  0.92  0.94  0.92        1.00
# Large Bags           -0.18          0.91  0.88  0.90  0.84        0.91
# XLarge Bags          -0.05          0.52  0.47  0.50  0.65        0.60
# year                  0.18         -0.00 -0.04 -0.01  0.03        0.09
# Month                 0.06         -0.06 -0.05 -0.06 -0.06       -0.05
#
#               Small Bags  Large Bags  XLarge Bags  year  Month
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %%
corr_matrix = df.corr()
corr_matrix["AveragePrice"].sort_values(ascending=True)
# Out:
# 4046           -0.19
# Large Bags     -0.18
# Total Volume   -0.14
# Total Bags     -0.11
# 4770           -0.10
# Small Bags     -0.10
# 4225           -0.09
# XLarge Bags    -0.05
# Month           0.06
# year            0.18
# AveragePrice    1.00
# Name: AveragePrice, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind="bar",color='c')
plt.xlabel("Feature",fontsize=14)
plt.ylabel("Column with target names",fontsize=14)
plt.title("Correlation with target",fontsize=14)
plt.show()

# %% [markdown]
# # Post Processing Data after EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  year          1517 non-null   float64
#  11  region        1517 non-null   object
#  12  Month         1517 non-null   int64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 165.9+ KB

# %%
df.nunique()
# Out:
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# year               2
# region            51
# Month             12
# dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** Before moving to model building we need to remove Date Column, as it is not needed. Also the Month column is a subset of it, so we can remove it.region we can add the label encoding, as we have to change the classification column to numerical values    </span>

# %% [markdown]
# ## Dropping Date & Month Column

# %%
df.drop(["Month"],axis=1, inplace=True)
df.head()
# Out:
#         Date  AveragePrice  Total Volume    4046      4225   4770  Total Bags  \
# 0 2015-12-27          1.33      64236.62 1036.74  54454.85  48.16     8696.87
# 1 2015-12-20          1.35      54876.98  674.28  44638.81  58.33     9505.56
# 2 2015-12-13          0.93     118220.22  794.70 109149.67 130.50     8145.35
# 3 2015-06-12          1.08      78992.15 1132.00  71976.41  72.58     5811.16
# 4 2015-11-29          1.28      51039.60  941.48  43838.39  75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  region
# 0     8603.62       93.25         0.00 2015.00  Albany
# 1     9408.07       97.49         0.00 2015.00  Albany
# 2     8042.21      103.14         0.00 2015.00  Albany
# 3     5677.40      133.76         0.00 2015.00  Albany
# 4     5986.26      197.69         0.00 2015.00  Albany

# %% [markdown]
# <span style='background:yellow'>**Observation:** Month is a subset Date Column, so we dropped that first and checked as well   </span>

# %%
df.drop(["Date"],axis=1, inplace=True)
df.head()
# Out:
#    AveragePrice  Total Volume    4046      4225   4770  Total Bags  \
# 0          1.33      64236.62 1036.74  54454.85  48.16     8696.87
# 1          1.35      54876.98  674.28  44638.81  58.33     9505.56
# 2          0.93     118220.22  794.70 109149.67 130.50     8145.35
# 3          1.08      78992.15 1132.00  71976.41  72.58     5811.16
# 4          1.28      51039.60  941.48  43838.39  75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  region
# 0     8603.62       93.25         0.00 2015.00  Albany
# 1     9408.07       97.49         0.00 2015.00  Albany
# 2     8042.21      103.14         0.00 2015.00  Albany
# 3     5677.40      133.76         0.00 2015.00  Albany
# 4     5986.26      197.69         0.00 2015.00  Albany

# %% [markdown]
# <span style='background:yellow'>**Observation:** Now Date column also has been removed and checked   </span>

# %% [markdown]
# # Label Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  1517 non-null   float64
#  1   Total Volume  1517 non-null   float64
#  2   4046          1517 non-null   float64
#  3   4225          1517 non-null   float64
#  4   4770          1517 non-null   float64
#  5   Total Bags    1517 non-null   float64
#  6   Small Bags    1517 non-null   float64
#  7   Large Bags    1517 non-null   float64
#  8   XLarge Bags   1517 non-null   float64
#  9   year          1517 non-null   float64
#  10  region        1517 non-null   object
# dtypes: float64(10), object(1)
# memory usage: 142.2+ KB

# %%
le = LabelEncoder()
df["region"] = le.fit_transform(df["region"])

# %%
df["region"].value_counts().sort_index()
# Out:
# 0     67
# 1     54
# 2     65
# 3     65
# 4     62
# 5     51
# 6     76
# 7     31
# 8     23
# 9     47
# 10    17
# 11    24
# 12    40
# 13    23
# 14    18
# 15    19
# 16    13
# 17    29
# 18    16
# 19    41
# 20    10
# 21     3
# 22    34
# 23    17
# 24    18
# 25    25
# 26    44
# 27    12
# 28    29
# 29    21
# 30    13
# 31    52
# 32    22
# 33    12
# 34    30
# 35    16
# 36    21
# 37    17
# 38    38
# 39    15
# 40     9
# 41    24
# 42    39
# 43     9
# 44    49
# 45    16
# 46    19
# 47    34
# 48    25
# 49    36
# 50    27
# Name: region, dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** we have converted Regions to numerical form and checked as well, and it is working fine   </span>

# %%
df['year'].value_counts().sort_index()
# Out:
# 2015.00    1270
# 2016.00     247
# Name: year, dtype: int64

# %%
le = LabelEncoder()
df["year"] = le.fit_transform(df["year"])

# %%
df['year'].value_counts().sort_index()
# Out:
# 0    1270
# 1     247
# Name: year, dtype: int64

# %% [markdown]
# <span style='background:yellow'>**Observation:** Year though not an object column, its more easier if we use it as simpler form, as only 2 years are there. So did label encoding 2015 is 0 and 2016 is 1 now    </span>

# %% [markdown]
# # Outlier

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'year', 'region'],
#       dtype='object')

# %%
#plotting box plot for the 1st 5 columns
df.iloc[:,0:1].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,1:5].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,5:9].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,9:10].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,10:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#abs is absolute value
#df [condition], whatever condition it matches, it retains and others are removed
#here z score <3, it is retained and Z> 3 is removed
from scipy.stats import zscore
z=np.abs(zscore(df))
df_out=df[(z<3).all(axis=1)]

# %%
df_out.shape
# Out:
# (1436, 11)

# %%
df.shape
# Out:
# (1517, 11)

# %%
((1517-1436)/1517)*100
# Out:
# 5.339485827290705

# %% [markdown]
# <span style='background:yellow'>**Observation:** 5% of our outliers have been removed. 5% of data is an acceptable norm to be removed, so we are good here   </span>

# %% [markdown]
# # Skewness

# %%
df_out.skew()
# Out:
# AveragePrice   -0.18
# Total Volume    2.70
# 4046            3.12
# 4225            2.37
# 4770            3.33
# Total Bags      4.17
# Small Bags      4.41
# Large Bags      3.52
# XLarge Bags     5.12
# year            2.00
# region          0.28
# dtype: float64

# %%
print("Number of numerical columns: ",len(df_out.skew()))
print("Number of columns which are skewed not in -0.5 to +0.5 range: ",len(df_out.skew().loc[abs(df_out.skew())>0.5]))
# Out:
# Number of numerical columns:  11
# Number of columns which are skewed not in -0.5 to +0.5 range:  9

# %% [markdown]
# <span style='background:pink'>**Note:** Before handling skewness lets remove our target column(y)   </span>

# %%
toskew_df2=df_out.drop(columns=["AveragePrice"])
y=df_out[["AveragePrice"]]

# %%
#lets treat the skewness in the X datset, for which skewness is present
import numpy as np
for index in toskew_df2.skew().index:
    if toskew_df2.skew().loc[index]>0.5:
        toskew_df2[index]=np.log1p(toskew_df2[index])
    if toskew_df2.skew().loc[index]<-0.5:
        toskew_df2[index]=np.square(toskew_df2[index])

# %%
#lets again check, how many columns are still skewed
print("Number of numerical columns: ",len(toskew_df2.skew()))
print("Number of columns which are skewed not in -0.5 to +0.5 range: ",len(toskew_df2.skew().loc[abs(toskew_df2.skew())>0.5]))
# Out:
# Number of numerical columns:  10
# Number of columns which are skewed not in -0.5 to +0.5 range:  2

# %%
toskew_df2.skew()
# Out:
# Total Volume    0.46
# 4046           -0.27
# 4225            0.01
# 4770           -0.45
# Total Bags      0.38
# Small Bags      0.42
# Large Bags      0.01
# XLarge Bags     0.85
# year            2.00
# region          0.28
# dtype: float64

# %% [markdown]
# <span style='background:yellow'>**Observation:** We have removed skewness from most columns and so we are good here. So continuing to standard scalar &  model building   </span>

# %% [markdown]
# # Standard Scalar

# %%
toskew_df2.describe()
# Out:
#        Total Volume    4046    4225    4770  Total Bags  Small Bags  \
# count       1436.00 1436.00 1436.00 1436.00     1436.00     1436.00
# mean          12.85   11.01   11.70    8.34       11.22       11.03
# std            1.26    2.20    1.56    2.45        1.18        1.19
# min           10.56    6.15    7.49    0.00        8.11        8.11
# 25%           11.86    9.81   10.60    6.67       10.45       10.24
# 50%           12.82   11.16   11.51    8.79       11.16       10.97
# 75%           13.64   12.49   12.92    9.95       11.77       11.62
# max           15.96   15.36   15.04   12.96       14.69       14.57
#
#        Large Bags  XLarge Bags    year  region
# count     1436.00      1436.00 1436.00 1436.00
# mean        68.82         2.47    0.10   20.88
# std         41.69         3.19    0.25   15.79
# min          0.00         0.00    0.00    0.00
# 25%         37.09         0.00    0.00    5.00
# 50%         69.79         0.00    0.00   19.00
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(toskew_df2)
x=sc.transform(toskew_df2)
x=pd.DataFrame(toskew_df2)

# %%
x.describe()
# Out:
#        Total Volume    4046    4225    4770  Total Bags  Small Bags  \
# count       1436.00 1436.00 1436.00 1436.00     1436.00     1436.00
# mean          12.85   11.01   11.70    8.34       11.22       11.03
# std            1.26    2.20    1.56    2.45        1.18        1.19
# min           10.56    6.15    7.49    0.00        8.11        8.11
# 25%           11.86    9.81   10.60    6.67       10.45       10.24
# 50%           12.82   11.16   11.51    8.79       11.16       10.97
# 75%           13.64   12.49   12.92    9.95       11.77       11.62
# max           15.96   15.36   15.04   12.96       14.69       14.57
#
#        Large Bags  XLarge Bags    year  region
# count     1436.00      1436.00 1436.00 1436.00
# mean        68.82         2.47    0.10   20.88
# std         41.69         3.19    0.25   15.79
# min          0.00         0.00    0.00    0.00
# 25%         37.09         0.00    0.00    5.00
# 50%         69.79         0.00    0.00   19.00
# ...

# %% [markdown]
# # Importing Libraries for Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score ,mean_absolute_error,mean_squared_error
from math import sqrt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Finding best Random state

# %%
maxAccu=0
BestRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)    
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        BestRs=i
print("Best accuracy is ", maxAccu,"on Random_state  ",BestRs)
# Out:
# Best accuracy is  0.4874626228893306 on Random_state   115

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=BestRs)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1148, 10)
# (288, 10)
# (1148, 1)
# (288, 1)

# %%
lm=LinearRegression()
ridge = Ridge()
gb= GradientBoostingRegressor()
dt  = DecisionTreeRegressor()
rf  = RandomForestRegressor()
knn = KNeighborsRegressor()
ls=Lasso()
svr=SVR()

# %% [markdown]
# ## Building Model with RMSE

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x,y,modelList):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(x_train,y_train)
        pred=modelInstance.predict(x_test)
        error=modelInstance.score(x_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x,y,cv=5,scoring='neg_root_mean_squared_error').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(RMSE-crossAcc)
        
    df_acc=pd.DataFrame({"Name":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "RMSECVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(x,y,modelList)
# Out:
#              Name  Error   R2  MAE  MSE  RMSE  CrossValidation  RMSECVDiff
# 0         Lin Reg   0.40 0.41 0.11 0.02  0.14            -0.17        0.31
# 1           Lasso   0.04 0.05 0.14 0.03  0.18            -0.18        0.36
# 2           Ridge   0.40 0.41 0.11 0.02  0.14            -0.17        0.31
# 3  Gradient boost   0.86 0.73 0.07 0.01  0.09            -0.16        0.25
# 4   Decision Tree   1.00 0.49 0.09 0.02  0.13            -0.20        0.33
# 5   Random Forest   0.98 0.81 0.06 0.01  0.08            -0.16        0.23
# 6        Kneigbor   0.74 0.60 0.08 0.01  0.11            -0.23        0.34

# %% [markdown]
# ## Building Model with R2

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x,y,modelList):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(x_train,y_train)
        pred=modelInstance.predict(x_test)
        error=modelInstance.score(x_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x,y,cv=5,scoring='r2').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(RMSE-crossAcc)
        
    df_acc=pd.DataFrame({"Name":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "R2CVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(x,y,modelList)
# Out:
#              Name  Error   R2  MAE  MSE  RMSE  CrossValidation  R2CVDiff
# 0         Lin Reg   0.37 0.47 0.11 0.02  0.14             0.05      0.10
# 1           Lasso   0.06 0.03 0.15 0.04  0.19            -0.06      0.25
# 2           Ridge   0.37 0.47 0.11 0.02  0.14             0.04      0.10
# 3  Gradient boost   0.84 0.79 0.07 0.01  0.09             0.17     -0.08
# 4   Decision Tree   1.00 0.71 0.08 0.01  0.11            -0.29      0.40
# 5   Random Forest   0.98 0.83 0.06 0.01  0.08             0.16     -0.08
# 6        Kneigbor   0.72 0.64 0.08 0.01  0.12            -0.80      0.91

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters ={
              "n_estimators":[10,100,500]
             }

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [10, 100, 500]})

# %%
GCV.best_params_
# Out:
# {'n_estimators': 500}

# %%
mod=RandomForestRegressor(n_estimators= 500)
mod.fit(x_train,y_train)
pred=mod.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.8508743427596659

# %% [markdown]
# # Ensemble Technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}

# %%
rf=RandomForestRegressor()

# %%
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_decision)
print("R2 Score:", rfs*100)
# Out:
# R2 Score: -10.875618238830853

# %%
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print("Cross Val Score:",rfc*100)
# Out:
# Cross Val Score: 19.32722481057622

# %% [markdown]
# # MOdel building by removing more columns

# %%
x.columns
# Out:
# Index(['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags',
#        'Large Bags', 'XLarge Bags', 'year', 'region'],
#       dtype='object')

# %%
df_out.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'year', 'region'],
#       dtype='object')

# %%
b=df_out.drop(columns=["AveragePrice",'XLarge Bags'])
y=df_out["AveragePrice"]

# %%
maxAccu=0
BestRs=0

for i in range(1,200):
    b_train,b_test,y_train,y_test=train_test_split(b,y,test_size=0.20,random_state=i)    
    mod=LinearRegression()
    mod.fit(b_train,y_train)
    pred=mod.predict(b_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        BestRs=i
print("Best accuracy is ", maxAccu,"on Random_state  ",BestRs)
# Out:
# Best accuracy is  0.27148708242623387 on Random_state   156

# %%
b_train,b_test,y_train,y_test=train_test_split(b,y,test_size=.20,random_state=BestRs)
print(b_train.shape)
print(b_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1148, 9)
# (288, 9)
# (1148,)
# (288,)

# %% [markdown]
# ## Building Model with RMSE (Feature Engineering)

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x,y,modelList):
    b_train,b_test,y_train,y_test=train_test_split(b,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(b_train,y_train)
        pred=modelInstance.predict(b_test)
        error=modelInstance.score(b_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,b,y,cv=5,scoring='r2').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(r2-crossAcc)
        
    df_acc=pd.DataFrame({"FEName":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "R2CVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(b,y,modelList)
# Out:
#            FEName  Error   R2  MAE  MSE  RMSE  CrossValidation  R2CVDiff
# 0         Lin Reg   0.21 0.25 0.12 0.02  0.16            -0.41      0.67
# 1           Lasso   0.18 0.22 0.12 0.03  0.16            -0.19      0.41
# 2           Ridge   0.21 0.25 0.12 0.02  0.16            -0.41      0.67
# 3  Gradient boost   0.86 0.74 0.07 0.01  0.09             0.09      0.64
# 4   Decision Tree   1.00 0.59 0.08 0.01  0.12            -0.39      0.99
# 5   Random Forest   0.98 0.81 0.06 0.01  0.08             0.19      0.62
# 6        Kneigbor   0.84 0.71 0.07 0.01  0.10            -0.04      0.75

# %% [markdown]
# ## Building Model with RMSE (Feature Engineering)

# %%
modelList=[("Lin Reg", lm), ("Lasso",ls),("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x,y,modelList):
    b_train,b_test,y_train,y_test=train_test_split(b,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(b_train,y_train)
        pred=modelInstance.predict(b_test)
        error=modelInstance.score(b_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,b,y,cv=5,scoring='neg_root_mean_squared_error').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(RMSE+crossAcc)
        
    df_acc=pd.DataFrame({"FEName":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "RMSECVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(b,y,modelList)
# Out:
#            FEName  Error   R2  MAE  MSE  RMSE  CrossValidation  RMSECVDiff
# 0         Lin Reg   0.21 0.25 0.12 0.02  0.16            -0.20       -0.04
# 1           Lasso   0.18 0.22 0.12 0.03  0.16            -0.19       -0.03
# 2           Ridge   0.21 0.25 0.12 0.02  0.16            -0.20       -0.04
# 3  Gradient boost   0.86 0.73 0.07 0.01  0.09            -0.16       -0.06
# 4   Decision Tree   1.00 0.59 0.08 0.01  0.12            -0.19       -0.08
# 5   Random Forest   0.98 0.81 0.06 0.01  0.08            -0.15       -0.07
# 6        Kneigbor   0.84 0.71 0.07 0.01  0.10            -0.17       -0.07

# %% [markdown]
# # PCA

# %%
#Lets use pca to reduce the dimensionality
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
x_pca=pca.fit_transform(x)
print("variance :{}".format(np.sum(pca.explained_variance_ratio_)))
# Out:
# variance :0.9999999999999999

# %% [markdown]
# ## PCA Model Building with R2

# %%
modelList=[("Lin Reg", lm),("Lasso",ls), ("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x_pca,y,modelList):
    xp_train,xp_test,y_train,y_test=train_test_split(x_pca,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(xp_train,y_train)
        pred=modelInstance.predict(xp_test)
        error=modelInstance.score(xp_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x_pca,y,cv=5,scoring='r2').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(r2-crossAcc)
        
    df_acc=pd.DataFrame({"PCAName":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "R2CVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(x_pca,y,modelList)
# Out:
#           PCAName  Error   R2  MAE  MSE  RMSE  CrossValidation  R2CVDiff
# 0         Lin Reg   0.40 0.41 0.11 0.02  0.14             0.05      0.36
# 1           Lasso   0.04 0.05 0.14 0.03  0.18            -0.05      0.11
# 2           Ridge   0.40 0.41 0.11 0.02  0.14             0.04      0.36
# 3  Gradient boost   0.86 0.71 0.08 0.01  0.10             0.07      0.64
# 4   Decision Tree   1.00 0.60 0.08 0.01  0.11            -0.87      1.47
# 5   Random Forest   0.97 0.76 0.07 0.01  0.09             0.13      0.63
# 6        Kneigbor   0.74 0.60 0.08 0.01  0.11            -0.80      1.40

# %% [markdown]
# ## PCA Model with RMSE

# %%
modelList=[("Lin Reg", lm),("Lasso",ls), ("Ridge", ridge),("Gradient boost",gb),("Decision Tree", dt),("Random Forest",rf),("Kneigbor",knn)]

def GetAccuracy(x_pca,y,modelList):
    xp_train,xp_test,y_train,y_test=train_test_split(x_pca,y,random_state=BestRs)
    modelerror=[]
    ModelName= []
    modelR2=[]
    modelMAE=[]
    modelMSE=[]
    modelRMSE=[]
    modelCrossval=[]
    R2CVDiff=[]
    for Nameofmodel, modelInstance in modelList:
        ModelName.append(Nameofmodel)
        modelInstance.fit(xp_train,y_train)
        pred=modelInstance.predict(xp_test)
        error=modelInstance.score(xp_train,y_train)
        modelerror.append(error)
        r2=r2_score(y_test,pred)
        modelR2.append(r2)
        mae = mean_absolute_error(y_test,pred)
        modelMAE.append(mae)
        MSE=mean_squared_error(y_test,pred)
        modelMSE.append(MSE)
        RMSE=sqrt(mean_squared_error(y_test,pred))
        modelRMSE.append(RMSE)
        
        crossAcc=cross_val_score(modelInstance,x_pca,y,cv=5,scoring='neg_root_mean_squared_error').mean()
        modelCrossval.append(crossAcc)
        R2CVDiff.append(RMSE+crossAcc)
        
    df_acc=pd.DataFrame({"PCAName":ModelName,
                         "Error":modelerror,
                         "R2": modelR2,
                         "MAE": modelMAE,
                         "MSE": modelMSE,
                         "RMSE": modelRMSE,                         
                         "CrossValidation":modelCrossval,
                         "RMSECVDiff":R2CVDiff
                          })
    return df_acc
GetAccuracy(x_pca,y,modelList)
# Out:
#           PCAName  Error   R2  MAE  MSE  RMSE  CrossValidation  RMSECVDiff
# 0         Lin Reg   0.40 0.41 0.11 0.02  0.14            -0.17       -0.03
# 1           Lasso   0.04 0.05 0.14 0.03  0.18            -0.18       -0.01
# 2           Ridge   0.40 0.41 0.11 0.02  0.14            -0.17       -0.03
# 3  Gradient boost   0.86 0.71 0.08 0.01  0.10            -0.17       -0.07
# 4   Decision Tree   1.00 0.61 0.08 0.01  0.11            -0.23       -0.12
# 5   Random Forest   0.97 0.76 0.07 0.01  0.09            -0.16       -0.08
# 6        Kneigbor   0.74 0.60 0.08 0.01  0.11            -0.23       -0.12

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(mod,"Avacado.pkl")
# Out:
# ['Avacado.pkl']

# %% [markdown]
# # Loading the Model

# %%
model=joblib.load("Avacado.pkl")

# %%
prediction=model.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-6ef2ed4bb5b6> in <module>
# ----> 1 prediction=model.predict(x_test)
#       2 print(r2_score(y_test,pred))
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#     223
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
prediction=pd.DataFrame(prediction) #converting to a Data Frame
prediction.head()  #checking the top 5 values, to double check fi there are predictions
