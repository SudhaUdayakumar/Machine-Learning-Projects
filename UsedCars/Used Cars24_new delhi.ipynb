# %% [markdown]
# # Used Car Web Scrapping

# %% [markdown]
# ## Importing the tools needed

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # Usedcars-New Delhi

# %%
url10='https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001'
driver.get(url10)


time.sleep(3)

# %%
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver.execute_script('return document.body.scrollHeight')
while True:
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height
    #scrapping urls 
    car_url4=[]
    for i in driver.find_elements_by_xpath("//a[@class='_9Ue0B']"):
        car_url4.append(i.get_attribute("href"))
print(len(car_url4)) #printing length of urls
# Out:
# 1815

# %%
#creating lists 

car_price10=[]
car_location10=[]
car_brand10=[]
car_fuel10=[]
car_drivKM10=[]
car_year10=[]
car_owners10=[]
car_year10=[]
car_hist10=[]
car_lastser10=[]
car_trans10=[]
car_reg10=[]
car_ins10=[]

# %%
time.sleep(2)
for i in car_url4:
    driver.get(i)
    

    #Brand
    try:
        brand10=driver.find_element_by_xpath("//h2[@class='_2geSF']")
        car_brand10.append(brand10.text)
    except NoSuchElementException:
        car_brand10.append('N/A')
        
    #Car Driver Kilometer 
    try:
        driven_km10=driver.find_element_by_xpath("//li[@class='tHlIu'][3]/strong")
        car_drivKM10.append(driven_km10.text)
    except NoSuchElementException:
        car_drivKM10.append('N/A')

     #Fuel type 
    try:
        fuel10=driver.find_element_by_xpath("//li[@class='tHlIu'][4]/strong")
        car_fuel10.append(fuel10.text)
    except NoSuchElementException:
        car_fuel10.append('N/A')
        
    #Number of owners 
    try:
        own10=driver.find_element_by_xpath("//li[@class='tHlIu'][2]/strong")
        car_owners10.append(own10.text)
    except NoSuchElementException:
        car_owners10.append('N/A')
        
    #Year of Purchase
    try:
        year10=driver.find_element_by_xpath("//li[@class='tHlIu'][9]/strong")
        car_year10.append(year10.text)
    except NoSuchElementException:
        car_year10.append('N/A')
    
    #Car History
    try:
        hist10=driver.find_element_by_xpath("//li[@class='tHlIu'][1]/strong")
        car_hist10.append(hist10.text)
    except NoSuchElementException:
        car_hist10.append('N/A')
        
    #Last Service 
    try:
        serv10=driver.find_element_by_xpath("//li[@class='tHlIu'][6]/strong")
        car_lastser10.append(serv10.text)
    except NoSuchElementException:
        car_lastser10.append('N/A')
        
    #Registeration 
    try: 
        reg10=driver.find_element_by_xpath("//li[@class='tHlIu'][7]/strong")
        car_reg10.append(reg10.text)
    except NoSuchElementException:
        car_reg10.append('N/A')
        
    #Insurance
    try:
        ins10=driver.find_element_by_xpath("//li[@class='tHlIu'][8]/strong")
        car_ins10.append(ins10.text)
    except NoSuchElementException: 
        car_ins10.append('N/A')
        
    #Price
    try:
        price10=driver.find_element_by_xpath("//strong[@class='_2yYvS']")
        car_price10.append(price10.text)
    except NoSuchElementException:
        car_price10.append('N/A')
        
    #location
    try:
        loc10=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[3]/div/div/strong")
        car_location10.append(loc10.text)
    except NoSuchElementException:
        car_location10.append("N/A")

# %%
UsedCars_24=pd.DataFrame({})
UsedCars_24['Brand']=car_brand10
UsedCars_24['Driven Kilometers ']=car_drivKM10
UsedCars_24['Fuel']=car_fuel10
UsedCars_24['Location']=car_location10
UsedCars_24['Year of Purchase']=car_year10
UsedCars_24['Price']=car_price10
UsedCars_24['Car History']=car_hist10
UsedCars_24['Last Service']=car_lastser10
UsedCars_24['Registeration']=car_reg10
UsedCars_24['Insurance']=car_ins10
UsedCars_24
# Out:
#                                              Brand Driven Kilometers     Fuel  \
# 0                     2013 Maruti Swift VDI MANUAL          11,019 km  Diesel
# 1     2012 Maruti Swift Dzire VXI 1.2 BS IV MANUAL          17,218 km  Petrol
# 2                     2012 Maruti Swift ZXI MANUAL          15,538 km  Petrol
# 3                  2017 Maruti Alto K10 LXI MANUAL           2,678 km  Petrol
# 4                  2011 Maruti Alto K10 VXI MANUAL          20,354 km  Petrol
# ...                                            ...                ...     ...
# 1810          2016 Honda BR-V 1.5 i-VTEC VX MANUAL         115,331 km  Petrol
# 1811      2017 Hyundai Elite i20 SPORTZ 1.2 MANUAL          50,141 km  Petrol
# 1812       2015 Honda City VX CVT PETROL AUTOMATIC          72,132 km  Petrol
# 1813                 2012 Maruti Ertiga ZDI MANUAL         120,093 km  Diesel
# 1814   2015 Hyundai Elite i20 ASTA 1.4 CRDI MANUAL         143,064 km  Diesel
#
#                                                Location Year of Purchase  \
# 0     Botanical Garden Metro Station, Sector 38, Noi...       April 2013
# 1     Botanical Garden Metro Station, Sector 38, Noi...      August 2012
# 2     Botanical Garden Metro Station, Sector 38, Noi...       April 2012
# 3     Botanical Garden Metro Station, Sector 38, Noi...              N/A
# 4     Botanical Garden Metro Station, Sector 38, Noi...       April 2011
# ...                                                 ...              ...
# 1810                                                           July 2016
# 1811                                                N/A        July 2017
# 1812                                                N/A              N/A
# 1813                                                N/A   September 2012
# 1814                                                N/A              N/A
#
#           Price     Car History  Last Service  \
# 0     ₹3,74,899  Non-Accidental        MANUAL
# 1     ₹3,53,799  Non-Accidental        MANUAL
# 2     ₹4,49,099  Non-Accidental        MANUAL
# 3     ₹2,77,799  Non-Accidental  DL-3C-x-xxxx
# 4     ₹2,17,099  Non-Accidental        MANUAL
# ...         ...             ...           ...
# 1810   ₹580,699  Non-Accidental        MANUAL
# 1811   ₹554,899  Non-Accidental        MANUAL
# 1812   ₹635,899  Non-Accidental  CH-01-x-xxxx
# 1813   ₹374,099  Non-Accidental        MANUAL
# 1814   ₹502,399  Non-Accidental  HR-03-x-xxxx
#
#                          Registeration                       Insurance
# 0                         DL-8C-x-xxxx  Valid upto Aug 2022\n3rd Party
# 1                         DL-4C-x-xxxx                     Third Party
# 2                         DL-6C-x-xxxx  Valid upto Aug 2022\n3rd Party
# 3     Valid upto Mar 2022\nThird_party                      March 2017
# 4                         DL-9C-x-xxxx  Valid upto Aug 2022\n3rd Party
# ...                                ...                             ...
# 1810                      CH-01-x-xxxx  Valid upto Aug 2022\n3rd Party
# 1811                      PB-10-x-xxxx  Valid upto Aug 2022\n3rd Party
# 1812         Valid upto Nov 2021\nComp                  September 2015
# 1813                      CH-01-x-xxxx       Valid upto Sep 2021\nComp
# 1814         Valid upto Jan 2022\nComp                    January 2015
#
# [1815 rows x 10 columns]

# %%
UsedCars_24.to_csv("Cars24_newdelhi.csv")
