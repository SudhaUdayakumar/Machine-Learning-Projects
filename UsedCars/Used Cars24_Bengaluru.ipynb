# %% [markdown]
# # Used Car Web Scrapping

# %% [markdown]
# ## Importing the tools needed

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # Usedcars-Bengalaru

# %%
url10='https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001'
driver.get(url10)


time.sleep(3)

# %%
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver.execute_script('return document.body.scrollHeight')
while True:
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height
    #scrapping urls 
    car_url4=[]
    for i in driver.find_elements_by_xpath("//a[@class='_9Ue0B']"):
        car_url4.append(i.get_attribute("href"))
print(len(car_url4)) #printing length of urls
# Out:
# 714

# %%
#creating lists 

car_price10=[]
car_location10=[]
car_brand10=[]
car_fuel10=[]
car_drivKM10=[]
car_year10=[]
car_owners10=[]
car_year10=[]
car_hist10=[]
car_lastser10=[]
car_trans10=[]
car_reg10=[]
car_ins10=[]

# %%
time.sleep(2)
for i in car_url4:
    driver.get(i)
    

    #Brand
    try:
        brand10=driver.find_element_by_xpath("//h2[@class='_2geSF']")
        car_brand10.append(brand10.text)
    except NoSuchElementException:
        car_brand10.append('N/A')
        
    #Car Driver Kilometer 
    try:
        driven_km10=driver.find_element_by_xpath("//li[@class='tHlIu'][3]/strong")
        car_drivKM10.append(driven_km10.text)
    except NoSuchElementException:
        car_drivKM10.append('N/A')

     #Fuel type 
    try:
        fuel10=driver.find_element_by_xpath("//li[@class='tHlIu'][4]/strong")
        car_fuel10.append(fuel10.text)
    except NoSuchElementException:
        car_fuel10.append('N/A')
        
    #Number of owners 
    try:
        own10=driver.find_element_by_xpath("//li[@class='tHlIu'][2]/strong")
        car_owners10.append(own10.text)
    except NoSuchElementException:
        car_owners10.append('N/A')
        
    #Year of Purchase
    try:
        year10=driver.find_element_by_xpath("//li[@class='tHlIu'][9]/strong")
        car_year10.append(year10.text)
    except NoSuchElementException:
        car_year10.append('N/A')
    
    #Car History
    try:
        hist10=driver.find_element_by_xpath("//li[@class='tHlIu'][1]/strong")
        car_hist10.append(hist10.text)
    except NoSuchElementException:
        car_hist10.append('N/A')
        
    #Last Service 
    try:
        serv10=driver.find_element_by_xpath("//li[@class='tHlIu'][6]/strong")
        car_lastser10.append(serv10.text)
    except NoSuchElementException:
        car_lastser10.append('N/A')
        
    #Registeration 
    try: 
        reg10=driver.find_element_by_xpath("//li[@class='tHlIu'][7]/strong")
        car_reg10.append(reg10.text)
    except NoSuchElementException:
        car_reg10.append('N/A')
        
    #Insurance
    try:
        ins10=driver.find_element_by_xpath("//li[@class='tHlIu'][8]/strong")
        car_ins10.append(ins10.text)
    except NoSuchElementException: 
        car_ins10.append('N/A')
        
    #Price
    try:
        price10=driver.find_element_by_xpath("//strong[@class='_2yYvS']")
        car_price10.append(price10.text)
    except NoSuchElementException:
        car_price10.append('N/A')
        
    #location
    try:
        loc10=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[3]/div/div/strong")
        car_location10.append(loc10.text)
    except NoSuchElementException:
        car_location10.append("N/A")

# %%
UsedCars_24=pd.DataFrame({})
UsedCars_24['Brand']=car_brand10
UsedCars_24['Driven Kilometers ']=car_drivKM10
UsedCars_24['Fuel']=car_fuel10
UsedCars_24['Location']=car_location10
UsedCars_24['Year of Purchase']=car_year10
UsedCars_24['Price']=car_price10
UsedCars_24['Car History']=car_hist10
UsedCars_24['Last Service']=car_lastser10
UsedCars_24['Registeration']=car_reg10
UsedCars_24['Insurance']=car_ins10
UsedCars_24
# Out:
#                                                  Brand Driven Kilometers   \
# 0                          2009 Maruti Alto LXI MANUAL          38,264 km
# 1                       2019 Maruti Celerio VXI MANUAL           3,283 km
# 2        2015 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL          15,107 km
# 3    2015 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT ...          10,520 km
# 4                          2010 Maruti Alto LXI MANUAL          32,291 km
# ..                                                 ...                ...
# 709                 2010 Maruti Swift Dzire VXI MANUAL          91,893 km
# 710             2009 Honda Jazz 1.2 BASE I VTEC MANUAL          74,956 km
# 711               2018 Maruti Vitara Brezza ZDI MANUAL          44,560 km
# 712       2012 Volkswagen Vento HIGHLINE DIESEL MANUAL          91,617 km
# 713                 2016 Mahindra XUV500 W8 FWD MANUAL          85,989 km
#
#        Fuel                                           Location  \
# 0    Petrol  S No. 123/3, Rajanna Layout, Agara Main Road, ...
# 1    Petrol  S No. 123/3, Rajanna Layout, Agara Main Road, ...
# 2    Petrol  S No. 123/3, Rajanna Layout, Agara Main Road, ...
# 3    Petrol  S No. 123/3, Rajanna Layout, Agara Main Road, ...
# 4    Petrol  S No. 123/3, Rajanna Layout, Agara Main Road, ...
# ..      ...                                                ...
# 709  Petrol                                                N/A
# 710  Petrol                                                N/A
# 711  Diesel                                                N/A
# 712  Diesel                                                N/A
# 713  Diesel                                                N/A
#
#     Year of Purchase      Price     Car History  Last Service  \
# 0          July 2009  ₹2,59,699  Non-Accidental        MANUAL
# 1        August 2019  ₹5,04,499  Non-Accidental        MANUAL
# 2         April 2015  ₹3,77,199  Non-Accidental        MANUAL
# 3          July 2015  ₹5,34,799  Non-Accidental        MANUAL
# 4         April 2010  ₹2,29,499  Non-Accidental        MANUAL
# ..               ...        ...             ...           ...
# 709        July 2010  ₹3,08,199  Non-Accidental        MANUAL
# 710         May 2009  ₹1,94,299  Non-Accidental        MANUAL
# 711              N/A  ₹8,60,999  Non-Accidental  KA-06-x-xxxx
# 712        June 2012  ₹3,80,099  Non-Accidental        MANUAL
# 713              N/A  ₹9,10,179  Non-Accidental  KA-36-x-xxxx
#
#                  Registeration                         Insurance
# 0                 KA-04-x-xxxx    Valid upto Aug 2022\n3rd Party
# 1                 KA-03-x-xxxx         Valid upto Oct 2021\nComp
# 2                 KA-04-x-xxxx    Valid upto Aug 2022\n3rd Party
# 3                 KA-53-x-xxxx         Valid upto Oct 2021\nComp
# 4                 KA-03-x-xxxx    Valid upto Aug 2022\n3rd Party
# ..                         ...                               ...
# 709               KA-03-x-xxxx    Valid upto Aug 2022\n3rd Party
# 710               MH-03-x-xxxx    Valid upto Aug 2022\n3rd Party
# 711  Valid upto Mar 2022\nComp                     February 2018
# 712               KA-02-x-xxxx  Valid upto Sep 2021\nThird_party
# 713                Third Party                      January 2016
#
# [714 rows x 10 columns]

# %%
UsedCars_24.to_csv("Cars24_bglr.csv")
