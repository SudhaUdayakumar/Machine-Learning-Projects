# %% [markdown]
# # Used Car Web Scrapping

# %% [markdown]
# ## Importing the tools needed

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # Usedcars-Ahmedabad

# %%
url10='https://www.cars24.com/buy-used-car?sort=P&storeCityId=1692&pinId=380001'
driver.get(url10)


time.sleep(3)

# %%
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver.execute_script('return document.body.scrollHeight')
while True:
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height
    #scrapping urls 
    car_url4=[]
    for i in driver.find_elements_by_xpath("//a[@class='_9Ue0B']"):
        car_url4.append(i.get_attribute("href"))
print(len(car_url4)) #printing length of urls
# Out:
# 332

# %%
#creating lists 

car_price10=[]
car_location10=[]
car_brand10=[]
car_fuel10=[]
car_drivKM10=[]
car_year10=[]
car_owners10=[]
car_year10=[]
car_hist10=[]
car_lastser10=[]
car_trans10=[]
car_reg10=[]
car_ins10=[]

# %%
time.sleep(2)
for i in car_url4:
    driver.get(i)
    

    #Brand
    try:
        brand10=driver.find_element_by_xpath("//h2[@class='_2geSF']")
        car_brand10.append(brand10.text)
    except NoSuchElementException:
        car_brand10.append('N/A')
        
    #Car Driver Kilometer 
    try:
        driven_km10=driver.find_element_by_xpath("//li[@class='tHlIu'][3]/strong")
        car_drivKM10.append(driven_km10.text)
    except NoSuchElementException:
        car_drivKM10.append('N/A')

     #Fuel type 
    try:
        fuel10=driver.find_element_by_xpath("//li[@class='tHlIu'][4]/strong")
        car_fuel10.append(fuel10.text)
    except NoSuchElementException:
        car_fuel10.append('N/A')
        
    #Number of owners 
    try:
        own10=driver.find_element_by_xpath("//li[@class='tHlIu'][2]/strong")
        car_owners10.append(own10.text)
    except NoSuchElementException:
        car_owners10.append('N/A')
        
    #Year of Purchase
    try:
        year10=driver.find_element_by_xpath("//li[@class='tHlIu'][9]/strong")
        car_year10.append(year10.text)
    except NoSuchElementException:
        car_year10.append('N/A')
    
    #Car History
    try:
        hist10=driver.find_element_by_xpath("//li[@class='tHlIu'][1]/strong")
        car_hist10.append(hist10.text)
    except NoSuchElementException:
        car_hist10.append('N/A')
        
    #Last Service 
    try:
        serv10=driver.find_element_by_xpath("//li[@class='tHlIu'][6]/strong")
        car_lastser10.append(serv10.text)
    except NoSuchElementException:
        car_lastser10.append('N/A')
        
    #Registeration 
    try: 
        reg10=driver.find_element_by_xpath("//li[@class='tHlIu'][7]/strong")
        car_reg10.append(reg10.text)
    except NoSuchElementException:
        car_reg10.append('N/A')
        
    #Insurance
    try:
        ins10=driver.find_element_by_xpath("//li[@class='tHlIu'][8]/strong")
        car_ins10.append(ins10.text)
    except NoSuchElementException: 
        car_ins10.append('N/A')
        
    #Price
    try:
        price10=driver.find_element_by_xpath("//strong[@class='_2yYvS']")
        car_price10.append(price10.text)
    except NoSuchElementException:
        car_price10.append('N/A')
        
    #location
    try:
        loc10=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[4]/div/div/div/div[3]/div/div/strong")
        car_location10.append(loc10.text)
    except NoSuchElementException:
        car_location10.append("N/A")

# %%
UsedCars_24=pd.DataFrame({})
UsedCars_24['Brand']=car_brand10
UsedCars_24['Driven Kilometers ']=car_drivKM10
UsedCars_24['Fuel']=car_fuel10
UsedCars_24['Location']=car_location10
UsedCars_24['Year of Purchase']=car_year10
UsedCars_24['Price']=car_price10
UsedCars_24['Car History']=car_hist10
UsedCars_24['Last Service']=car_lastser10
UsedCars_24['Registeration']=car_reg10
UsedCars_24['Insurance']=car_ins10
UsedCars_24
# Out:
#                                              Brand Driven Kilometers   \
# 0           2020 Maruti IGNIS SIGMA 1.2 K12 MANUAL           3,142 km
# 1                      2020 Maruti Alto VXI MANUAL             840 km
# 2                  2017 Maruti Alto 800 LXI MANUAL           5,800 km
# 3                     2015 Maruti Swift VXI MANUAL          24,028 km
# 4    2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL           1,999 km
# ..                                             ...                ...
# 327            2014 Hyundai i20 MAGNA O 1.2 MANUAL          87,944 km
# 328             2013 Maruti Wagon R 1.0 LXI MANUAL        1,12,304 km
# 329             2010 Honda City V MT PETROL MANUAL        2,00,273 km
# 330             2013 Maruti Wagon R 1.0 LXI MANUAL        1,34,680 km
# 331       2013 Hyundai i10 MAGNA 1.2 KAPPA2 MANUAL        1,58,876 km
#
#              Fuel                                           Location  \
# 0          Petrol  Chandani Party Plot, Dr Jivraj Mehta Marg, Sar...
# 1          Petrol  Chandani Party Plot, Dr Jivraj Mehta Marg, Sar...
# 2          Petrol  Chandani Party Plot, Dr Jivraj Mehta Marg, Sar...
# 3          Petrol  Chandani Party Plot, Dr Jivraj Mehta Marg, Sar...
# 4          Petrol  Chandani Party Plot, Dr Jivraj Mehta Marg, Sar...
# ..            ...                                                ...
# 327        Petrol  Shop No-228, 1st floor Iskcon mall, Opp. Rajha...
# 328        Petrol  Shop No-228, 1st floor Iskcon mall, Opp. Rajha...
# 329        Petrol  Shop No-228, 1st floor Iskcon mall, Opp. Rajha...
# 330        Petrol  Shop No-228, 1st floor Iskcon mall, Opp. Rajha...
# 331  Petrol + CNG                                                N/A
#
#     Year of Purchase      Price     Car History  Last Service  \
# 0                N/A  ₹5,26,500  Non-Accidental  GJ-01-x-xxxx
# 1                N/A  ₹4,09,899  Non-Accidental  GJ-18-x-xxxx
# 2         March 2017  ₹2,99,299  Non-Accidental        MANUAL
# 3      February 2015  ₹4,63,599  Non-Accidental        MANUAL
# 4      February 2020  ₹4,99,299  Non-Accidental        MANUAL
# ..               ...        ...             ...           ...
# 327         May 2014  ₹3,85,799  Non-Accidental        MANUAL
# 328        July 2013  ₹2,43,099  Non-Accidental        MANUAL
# 329       April 2010  ₹3,27,199  Non-Accidental        MANUAL
# 330        June 2013  ₹2,23,199  Non-Accidental        MANUAL
# 331        June 2013  ₹2,43,999  Non-Accidental        MANUAL
#
#                      Registeration                         Insurance
# 0    Valid upto Oct 2021\nZero_Dep                      October 2020
# 1    Valid upto Jan 2022\nZero_Dep                     December 2020
# 2                     GJ-05-x-xxxx    Valid upto Aug 2022\n3rd Party
# 3                     GJ-05-x-xxxx    Valid upto Aug 2022\n3rd Party
# 4                     GJ-01-x-xxxx    Valid upto Aug 2022\n3rd Party
# ..                             ...                               ...
# 327                   GJ-27-x-xxxx    Valid upto Aug 2022\n3rd Party
# 328                   GJ-01-x-xxxx         Valid upto Aug 2021\nComp
# 329                   GJ-1K-x-xxxx    Valid upto Aug 2022\n3rd Party
# 330                   GJ-05-x-xxxx  Valid upto Sep 2021\nThird_party
# 331                   GJ-18-x-xxxx         Valid upto Aug 2021\nComp
#
# [332 rows x 10 columns]

# %%
UsedCars_24.to_csv("Cars24_Ahmedabad.csv")
